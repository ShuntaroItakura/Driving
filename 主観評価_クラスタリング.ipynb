# %%
# #エクセルファイル　読み込み
# import openpyxl

# #エクセルファイルを開く
# wb = openpyxl.load_workbook('主観評価再編成.xlsx')
# wb

# %%
import pandas as pd
X = pd.read_excel('主観評価設問状態_origin_出力100.xlsx')
X
# Out:
#      好み1  不快1  個人的に好き1  なぜ危険なのか1  どのように改善したらよいか1  なるほど1  自分には関係ない1  改善しようと思う1  \
# 0      1    3        2         1               1      1          3          3
# 1      3    3        3         3               3      3          3          3
# 2      1    5        1         1               5      1          5          1
# 3      3    3        3         1               5      1          1          1
# 4      1    1        1         1               1      1          1          1
# ..   ...  ...      ...       ...             ...    ...        ...        ...
# 799    3    5        3         1               1      1          3          1
# 800    1    5        1         1               5      1          5          1
# 801    5    1        5         5               1      4          1          5
# 802    1    5        1         1               5      1          1          1
# 803    1    5        1         1               5      1          5          1
#
# ...

# %%
X.columns
# Out:
# Index(['好み1', '不快1', '個人的に好き1', 'なぜ危険なのか1', 'どのように改善したらよいか1', 'なるほど1',
#        '自分には関係ない1', '改善しようと思う1', 'これからは注意して運転しよう1', '急ブレーキのたびに出たら不快1',
#        'たまに出てきても問題ない1', '何度も出てきたら煩わしく1', 'ブレーキに関する内容1', '自分の運転に対する内容1',
#        '何の操作に対する指摘かよくわからなかった1', '分かりやすかった1', '理解しやすかった1', '指摘内容の把握を流暢に1',
#        '把握は楽1', '難しかった1', '好み2', '不快2', '個人的に好き2', 'なぜ危険なのか2',
#        'どのように改善したらよいか2', 'なるほど2', '自分には関係ない2', '改善しようと思う2', 'これからは注意して運転しよう2',
#        '急ブレーキのたびに出たら不快2', 'たまに出てきても問題ない2', '何度も出てきたら煩わしく2', 'ブレーキに関する内容2',
#        '自分の運転に対する内容2', '何の操作に対する指摘かよくわからなかった2', '分かりやすかった2', '理解しやすかった2',
#        '指摘内容の把握を流暢に2', '把握は楽2', '難しかった2', '好み3', '不快3', '個人的に好き3', 'なぜ危険なのか3',
#        'どのように改善したらよいか3', 'なるほど3', '自分には関係ない3', '改善しようと思う3', 'これからは注意して運転しよう3',
#        '急ブレーキのたびに出たら不快3', 'たまに出てきても問題ない3', '何度も出てきたら煩わしく3', 'ブレーキに関する内容3',
#        '自分の運転に対する内容3', '何の操作に対する指摘かよくわからなかった3', '分かりやすかった3', '理解しやすかった3',
#        '指摘内容の把握を流暢に3', '把握は楽3', '難しかった3', '好み4', '不快4', '個人的に好き4', 'なぜ危険なのか4',
# ...

# %%
X1 = X[['好み1', '不快1', '個人的に好き1', 'なぜ危険なのか1', 'どのように改善したらよいか1', 'なるほど1',
       '自分には関係ない1', '改善しようと思う1', 'これからは注意して運転しよう1', '急ブレーキのたびに出たら不快1',
       'たまに出てきても問題ない1', '何度も出てきたら煩わしく1', 'ブレーキに関する内容1', '自分の運転に対する内容1',
       '何の操作に対する指摘かよくわからなかった1', '分かりやすかった1', '理解しやすかった1', '指摘内容の把握を流暢に1',
       '把握は楽1', '難しかった1']]
X2 = X[['好み2', '不快2', '個人的に好き2', 'なぜ危険なのか2', 'どのように改善したらよいか2', 'なるほど2',
       '自分には関係ない2', '改善しようと思う2', 'これからは注意して運転しよう2', '急ブレーキのたびに出たら不快2',
       'たまに出てきても問題ない2', '何度も出てきたら煩わしく2', 'ブレーキに関する内容2', '自分の運転に対する内容2',
       '何の操作に対する指摘かよくわからなかった2', '分かりやすかった2', '理解しやすかった2', '指摘内容の把握を流暢に2',
       '把握は楽2', '難しかった2']]
X3 = X[['好み3', '不快3', '個人的に好き3', 'なぜ危険なのか3', 'どのように改善したらよいか3', 'なるほど3',
       '自分には関係ない3', '改善しようと思う3', 'これからは注意して運転しよう3', '急ブレーキのたびに出たら不快3',
       'たまに出てきても問題ない3', '何度も出てきたら煩わしく3', 'ブレーキに関する内容3', '自分の運転に対する内容3',
       '何の操作に対する指摘かよくわからなかった3', '分かりやすかった3', '理解しやすかった3', '指摘内容の把握を流暢に3',
       '把握は楽3', '難しかった3']]
X4 = X[['好み4', '不快4', '個人的に好き4', 'なぜ危険なのか4', 'どのように改善したらよいか4', 'なるほど4',
       '自分には関係ない4', '改善しようと思う4', 'これからは注意して運転しよう4', '急ブレーキのたびに出たら不快4',
       'たまに出てきても問題ない4', '何度も出てきたら煩わしく4', 'ブレーキに関する内容4', '自分の運転に対する内容4',
       '何の操作に対する指摘かよくわからなかった4', '分かりやすかった4', '理解しやすかった4', '指摘内容の把握を流暢に4',
       '把握は楽4', '難しかった4']]
X5 = X[['好み5', '不快5', '個人的に好き5', 'なぜ危険なのか5', 'どのように改善したらよいか5', 'なるほど5',
       '自分には関係ない5', '改善しようと思う5', 'これからは注意して運転しよう5', '急ブレーキのたびに出たら不快5',
       'たまに出てきても問題ない5', '何度も出てきたら煩わしく5', 'ブレーキに関する内容5', '自分の運転に対する内容5',
       '何の操作に対する指摘かよくわからなかった5', '分かりやすかった5', '理解しやすかった5', '指摘内容の把握を流暢に5',
       '把握は楽5', '難しかった5']]

# %%
np_X1 = X1.to_numpy()
np_X2 = X2.to_numpy()
np_X3 = X3.to_numpy()
np_X4 = X4.to_numpy()
np_X5 = X5.to_numpy()

print(np_X1[0,0], np_X2[0,0], np_X3[0,0], np_X4[0,0], np_X5[0,0])
# Out:
# 1 3 3 3 3

# %%
import numpy as np
np_X = np.dstack([np_X1, np_X2, np_X3, np_X4, np_X5])

# %%
#np_Xに対
