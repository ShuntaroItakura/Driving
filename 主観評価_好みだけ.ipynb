# %%
#エクセルファイル　読み込み
import openpyxl

#エクセルファイルを開く
wb = openpyxl.load_workbook('主観評価再編成.xlsx')
wb

# %%
import pandas as pd
pd.read_excel('主観評価設問状態_origin_出力100.xlsx')
# Out:
#      好み1  不快1  個人的に好き1  なぜ危険なのか1  どのように改善したらよいか1  なるほど1  自分には関係ない1  改善しようと思う1  \
# 0      1    3        2         1               1      1          3          3
# 1      3    3        3         3               3      3          3          3
# 2      1    5        1         1               5      1          5          1
# 3      3    3        3         1               5      1          1          1
# 4      1    1        1         1               1      1          1          1
# ..   ...  ...      ...       ...             ...    ...        ...        ...
# 799    3    5        3         1               1      1          3          1
# 800    1    5        1         1               5      1          5          1
# 801    5    1        5         5               1      4          1          5
# 802    1    5        1         1               5      1          1          1
# 803    1    5        1         1               5      1          5          1
#
# ...

# %%
import pandas as pd
s = pd.read_excel('主観評価設問状態_origin_出力100.xlsx')

s1 = s[['好み1', '不快1', '個人的に好き1', 'なぜ危険なのか1', 'どのように改善したらよいか1', 'なるほど1',
       '自分には関係ない1', '改善しようと思う1', 'これからは注意して運転しよう1', '急ブレーキのたびに出たら不快1',
       'たまに出てきても問題ない1', '何度も出てきたら煩わしく1', 'ブレーキに関する内容1', '自分の運転に対する内容1',
       '何の操作に対する指摘かよくわからなかった1', '分かりやすかった1', '理解しやすかった1', '指摘内容の把握を流暢に1',
       '把握は楽1', '難しかった1']]
s2 = s[['好み2', '不快2', '個人的に好き2', 'なぜ危険なのか2',
       'どのように改善したらよいか2', 'なるほど2', '自分には関係ない2', '改善しようと思う2', 'これからは注意して運転しよう2',
       '急ブレーキのたびに出たら不快2', 'たまに出てきても問題ない2', '何度も出てきたら煩わしく2', 'ブレーキに関する内容2',
       '自分の運転に対する内容2', '何の操作に対する指摘かよくわからなかった2', '分かりやすかった2', '理解しやすかった2',
       '指摘内容の把握を流暢に2', '把握は楽2', '難しかった2']]
s3 = s[['好み3', '不快3', '個人的に好き3', 'なぜ危険なのか3',
       'どのように改善したらよいか3', 'なるほど3', '自分には関係ない3', '改善しようと思う3', 'これからは注意して運転しよう3',
       '急ブレーキのたびに出たら不快3', 'たまに出てきても問題ない3', '何度も出てきたら煩わしく3', 'ブレーキに関する内容3',
       '自分の運転に対する内容3', '何の操作に対する指摘かよくわからなかった3', '分かりやすかった3', '理解しやすかった3',
       '指摘内容の把握を流暢に3', '把握は楽3', '難しかった3']]
s4 = s[['好み4', '不快4', '個人的に好き4', 'なぜ危険なのか4',
       'どのように改善したらよいか4', 'なるほど4', '自分には関係ない4', '改善しようと思う4', 'これからは注意して運転しよう4',
       '急ブレーキのたびに出たら不快4', 'たまに出てきても問題ない4', '何度も出てきたら煩わしく4', 'ブレーキに関する内容4',
       '自分の運転に対する内容4', '何の操作に対する指摘かよくわからなかった4', '分かりやすかった4', '理解しやすかった4',
       '指摘内容の把握を流暢に4', '把握は楽4', '難しかった4']]
s5 = s[['好み5', '不快5', '個人的に好き5', 'なぜ危険なのか5',
       'どのように改善したらよいか5', 'なるほど5', '自分には関係ない5', '改善しようと思う5', 'これからは注意して運転しよう5',
       '急ブレーキのたびに出たら不快5', 'たまに出てきても問題ない5', '何度も出てきたら煩わしく5', 'ブレーキに関する内容5',
       '自分の運転に対する内容5', '何の操作に対する指摘かよくわからなかった5', '分かりやすかった5', '理解しやすかった5',
       '指摘内容の把握を流暢に5', '把握は楽5', '難しかった5']]

# %%
# import matplotlib.pyplot as plt 

# # 質問ごとの分布を可視化する関数
# def plot_question_distribution(s1, s2, s3, s4, s5, question_prefix):
#     plt.figure(figsize=(12, 8))
    
#     # 各提示方法のデータをまとめる
#     data = pd.concat([s1[question_prefix+'1'], s2[question_prefix+'2'], s3[question_prefix+'3'], 
#                       s4[question_prefix+'4'], s5[question_prefix+'5']], axis=1)
    
#     # 提示方法ごとのラベルを追加
#     data.columns = ['Method1', 'Method2', 'Method3', 'Method4', 'Method5']
    
#     # ヒストグラムの描画
#     data.plot(kind='hist', alpha=0.5, bins=5, figsize=(12, 8), title=f'Distribution of {question_prefix}')
#     plt.xlabel('Response')
#     plt.ylabel('Frequency')
#     plt.legend(['Method1', 'Method2', 'Method3', 'Method4', 'Method5'])
#     plt.show()

# # 各質問ごとに分布を確認する
# question_list = ['好み', '不快', '個人的に好き', 'なぜ危険なのか', 'どのように改善したらよいか',
#                  'なるほど', '自分には関係ない', '改善しようと思う', 'これからは注意して運転しよう',
#                  '急ブレーキのたびに出たら不快', 'たまに出てきても問題ない', '何度も出てきたら煩わしく',
#                  'ブレーキに関する内容', '自分の運転に対する内容', '何の操作に対する指摘かよくわからなかった',
#                  '分かりやすかった', '理解しやすかった', '指摘内容の把握を流暢に', '把握は楽', '難しかった']

# for question in question_list:
#     plot_question_distribution(s1, s2, s3, s4, s5, question)

# %%
s1.iloc[:,0]
import japanize_matplotlib
pref0 = pd.concat([s1.iloc[:,0], s2.iloc[:,0], s3.iloc[:,0], s4.iloc[:,0], s5.iloc[:,0]], axis=1)
pref0.columns = ['好み提示なし', '好み画像のみ', '好み音声のみ', '好み画像＋報知音', '好み画像+音声']
pref0
# Out:
#      好み提示なし  好み画像のみ  好み音声のみ  好み画像＋報知音  好み画像+音声
# 0         1       3       3         3        3
# 1         3       3       3         3        3
# 2         1       1       1         2        4
# 3         3       3       4         3        4
# 4         1       4       4         3        5
# ..      ...     ...     ...       ...      ...
# 799       3       2       3         3        3
# 800       1       2       3         3        3
# 801       5       5       5         5        5
# 802       1       4       3         4        4
# 803       1       3       3         3        3
#
# [804 rows x 5 columns]

# %%
pref1 = pd.concat([s1.iloc[:,1], s2.iloc[:,1], s3.iloc[:,1], s4.iloc[:,1], s5.iloc[:,1]], axis=1)
pref1.columns = ['不快提示なし', '不快画像のみ', '不快音声のみ', '不快画像＋報知音', '不快画像+音声']
pref1
# Out:
#      不快提示なし  不快画像のみ  不快音声のみ  不快画像＋報知音  不快画像+音声
# 0         3       3       5         4        4
# 1         3       3       3         3        3
# 2         5       5       4         3        1
# 3         3       4       4         4        4
# 4         1       5       5         5        5
# ..      ...     ...     ...       ...      ...
# 799       5       5       5         5        5
# 800       5       3       4         3        3
# 801       1       1       1         1        1
# 802       5       5       5         4        4
# 803       5       4       5         5        5
#
# [804 rows x 5 columns]

# %%
pref2 = pd.concat([s1.iloc[:,2], s2.iloc[:,2], s3.iloc[:,2], s4.iloc[:,2], s5.iloc[:,2]], axis=1)
pref2.columns = ['個人的に好き提示なし', '個人的に好き画像のみ', '個人的に好き音声のみ', '個人的に好き画像＋報知音', '個人的に好き画像+音声']
pref2.head(10)
# Out:
#    個人的に好き提示なし  個人的に好き画像のみ  個人的に好き音声のみ  個人的に好き画像＋報知音  個人的に好き画像+音声
# 0           2           3           3             3            2
# 1           3           3           3             3            3
# 2           1           1           2             2            5
# 3           3           3           3             3            3
# 4           1           5           5             3            5
# 5           3           3           3             3            4
# 6           3           3           3             3            3
# 7           2           3           4             4            4
# 8           3           2           2             3            3
# 9           3           2           4             2            4

# %%
pref = pd.DataFrame(index=range(804), columns=range(5))
for i in range(5):
    for j in range(804):
        pref.iloc[j,i] = pref0.iloc[j,i] + pref1.iloc[j,i] + pref2.iloc[j,i]
pref
# Out:
#       0   1   2   3   4
# 0     6   9  11  10   9
# 1     9   9   9   9   9
# 2     7   7   7   7  10
# 3     9  10  11  10  11
# 4     3  14  14  11  15
# ..   ..  ..  ..  ..  ..
# 799  11   9  11  11  11
# 800   7   6   9   8   7
# 801  11  11  11  11  11
# 802   7  12  12  10  12
# 803   7  10  11  11  11
#
# [804 rows x 5 columns]

# %%
age = pd.read_csv('surbay_data.csv')
age.head()
# Out:
#    age   age_bin
# 0   28  [19, 30)
# 1   28  [19, 30)
# 2   28  [19, 30)
# 3   20  [19, 30)
# 4   27  [19, 30)

# %%
#prefの最大値が何回出たか（どのくらい点数が被っているか）

for i in range(20):
    a = pref
    a['max_value'] = a.max(axis=1)

    a['max_count'] = a.apply(lambda row: list(row).count(row['max_value']) - 1, axis=1)

# %%
pref_age = pd.concat([pref, age], axis=1)
pref_age


pref_age_drop = pref_age[pref_age['max_count'] == 1]
pref_age_drop.columns
# Out:
# Index([0, 1, 2, 3, 4, 'max_value', 'max_count', 'age', 'age_bin'], dtype='object')

# %%
# 1. 0, 1, 2, 3, 4 の中で最大値のインデックスをラベルとして追加
pref_age_drop['label'] = pref_age_drop[[0,1,2,3,4]].idxmax(axis=1)
pref_age_drop
# Out:
# /var/folders/5r/3m3ng3v11j57dkl0psc9lphh0000gn/T/ipykernel_23032/3127743449.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   pref_age_drop['label'] = pref_age_drop[[0,1,2,3,4]].idxmax(axis=1)
#      0   1   2   3   4 max_value  max_count  age   age_bin label
# 0    6   9  11  10   9        11          1   28  [19, 30)     2
# 2    7   7   7   7  10        10          1   28  [19, 30)     4
# 4    3  14  14  11  15        15          1   27  [19, 30)     4
# 5    9  10   9   9  11        11          1   24  [19, 30)     4
# 7    8   9  11  10  10        11          1   27  [19, 30)     2
# ..  ..  ..  ..  ..  ..       ...        ...  ...       ...   ...
# 792  3   8   8   7  14        14          1   70  [70, 83)     4
# ...

# %%
pref_age_drop['age_bin'].value_counts()
# Out:
# age_bin
# [60, 70)    87
# [30, 40)    81
# [19, 30)    77
# [40, 50)    73
# [50, 60)    71
# [70, 83)    62
# Name: count, dtype: int64

# %%
# 2. 年齢区分ごとのラベルの分布を集計
age_bin_label_distribution = pref_age_drop.groupby(['age_bin', 'label']).size().unstack(fill_value=0)
age_bin_label_distribution
# Out:
# label      0   1   2   3   4
# age_bin
# [19, 30)   5  16  17  21  18
# [30, 40)  13  10  23  19  16
# [40, 50)  11   3  22  14  23
# [50, 60)   7   7  28   9  20
# [60, 70)   7  14  25  13  28
# [70, 83)   4   6  20  10  22

# %%
#age_bin_label_distributionをヒートマップで可視化
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(12, 8))
sns.heatmap(age_bin_label_distribution, fmt='d',annot=True,  cmap='coolwarm')
plt.title('Age Bin vs Label Distribution')
plt.xlabel('Label')
plt.ylabel('Age Bin')
plt.show()

# %%
df1 = pd.read_excel('主観評価設問状態_origin.xlsx', sheet_name='Sheet1')
col = df1.columns

# %%
#pref0の最大値が何回出たか（どのくらい点数が被っているか）

for i in range(20):
    a = pref0
    a['max_value'] = a.max(axis=1)

    a['max_count'] = a.apply(lambda row: list(row).count(row['max_value']) - 1, axis=1)

a[a['max_count'] == 1]
# Out:
#      好み提示なし  好み画像のみ  好み音声のみ  好み画像＋報知音  好み画像+音声  max_value  max_count
# 2         1       1       1         2        4          4          1
# 4         1       4       4         3        5          5          1
# 5         3       3       3         3        4          4          1
# 9         3       2       2         2        2          3          1
# 14        1       1       3         4        1          4          1
# ..      ...     ...     ...       ...      ...        ...        ...
# 789       3       3       4         2        3          4          1
# 790       1       3       2         4        3          4          1
# 792       1       2       2         1        5          5          1
# 794       3       1       4         2        3          4          1
# 796       1       1       4         1        2          4          1
#
# [291 rows x 7 columns]

# %%
#pref1の最大値が何回出たか（どのくらい点数が被っているか）

for i in range(20):
    a = pref1
    a['max_value'] = a.max(axis=1)

    a['max_count'] = a.apply(lambda row: list(row).count(row['max_value']) - 1, axis=1)

a[a['max_count'] == 1]
# Out:
#      不快提示なし  不快画像のみ  不快音声のみ  不快画像＋報知音  不快画像+音声  max_value  max_count
# 0         3       3       5         4        4          5          1
# 5         3       4       3         3        3          4          1
# 12        5       4       3         4        2          5          1
# 13        4       3       3         3        2          4          1
# 15        3       3       3         4        3          4          1
# ..      ...     ...     ...       ...      ...        ...        ...
# 789       4       4       5         3        3          5          1
# 791       5       3       2         2        3          5          1
# 794       3       3       5         3        3          5          1
# 796       2       2       5         1        3          5          1
# 800       5       3       4         3        3          5          1
#
# [267 rows x 7 columns]

# %%
#pref2の最大値が何回出たか（どのくらい点数が被っているか）

for i in range(20):
    a = pref2
    a['max_value'] = a.max(axis=1)

    a['max_count'] = a.apply(lambda row: list(row).count(row['max_value']) - 1, axis=1)

a[a['max_count'] == 1]
# Out:
#      個人的に好き提示なし  個人的に好き画像のみ  個人的に好き音声のみ  個人的に好き画像＋報知音  個人的に好き画像+音声  max_value  \
# 2             1           1           2             2            5          5
# 5             3           3           3             3            4          4
# 12            1           4           3             3            3          4
# 13            2           4           3             3            3          4
# 14            1           1           1             3            1          3
# ..          ...         ...         ...           ...          ...        ...
# 784           1           4           3             3            3          4
# 789           2           3           4             2            2          4
# 791           3           3           3             4            2          4
# 792           1           1           1             1            4          4
# 794           2           1           4             1            3          4
#
#      max_count
# 2            1
# ...

# %%
#prefの最大値が何回出たか（どのくらい点数が被っているか）

for i in range(20):
    a = pref_age
    a['max_value'] = a.max(axis=1)

    a['max_count'] = a.apply(lambda row: list(row).count(row['max_value']) - 1, axis=1)

a[a['max_count'] == 1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[65], line 5
#       3 for i in range(20):
#       4     a = pref_age
# ----> 5     a['max_value'] = a.max(axis=1)
#       7     a['max_count'] = a.apply(lambda row: list(row).count(row['max_value']) - 1, axis=1)
#       9 a[a['max_count'] == 1]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:11298, in DataFrame.max(self, axis, skipna, numeric_only, **kwargs)
#   11290 @doc(make_doc("max", ndim=2))
#   11291 def max(
#   11292     self,
#    (...)
#   11296     **kwargs,
#   11297 ):
# > 11298     result = super().max(axis, skipna, numeric_only, **kwargs)
#   11299     if isinstance(result, Series):
#   11300         result = result.__finalize__(self, method="max")
#
# ...

# %%
#prefの中でmax_countが1のものを抽出
a = pref

a['max_count'] = a.apply(lambda row: list(row).count(row['max_value']) - 1, axis=1)

# %%
#最大値が何回出たか（どのくらい点数が被っているか）
#

b= {}
for i in range(20):
    a = pd.concat([s1.iloc[:,i], s2.iloc[:,i], s3.iloc[:,i], s4.iloc[:,i], s5.iloc[:,i]], axis=1)
    a['max_value'] = a.max(axis=1)

    a['max_count'] = a.apply(lambda row: list(row).count(row['max_value']) - 1, axis=1)
    a_drop = a[a['max_count'] == 1]
    print(len(a_drop))
    
    b[col[i]] = len(a_drop)
    
    print(a_drop)
# Out:
# 291
#      好み1  好み2  好み3  好み4  好み5  max_value  max_count
# 2      1    1    1    2    4          4          1
# 4      1    4    4    3    5          5          1
# 5      3    3    3    3    4          4          1
# 9      3    2    2    2    2          3          1
# 14     1    1    3    4    1          4          1
# ..   ...  ...  ...  ...  ...        ...        ...
# 789    3    3    4    2    3          4          1
# 790    1    3    2    4    3          4          1
# 792    1    2    2    1    5          5          1
# 794    3    1    4    2    3          4          1
# 796    1    1    4    1    2          4          1
#
# [291 rows x 7 columns]
# 267
#      不快1  不快2  不快3  不快4  不快5  max_value  max_count
# 0      3    3    5    4    4          5          1
# 5      3    4    3    3    3          4          1
# 12     5    4    3    4    2          5          1
# 13     4    3    3    3    2          4          1
# 15     3    3    3    4    3          4          1
# ...

# %%
b
# Out:
# {'好み': 291,
#  '不快': 267,
#  '個人的に好き': 264,
#  'なぜ危険なのか': 214,
#  'どのように改善したらよいか': 233,
#  'なるほど': 211,
#  '自分には関係ない': 236,
#  '改善しようと思う': 184,
#  'これからは注意して運転しよう': 179,
#  '急ブレーキのたびに出たら不快': 311,
#  'たまに出てきても問題ない': 417,
#  '何度も出てきたら煩わしく': 291,
#  'ブレーキに関する内容': 161,
#  '自分の運転に対する内容': 178,
#  '何の操作に対する指摘かよくわからなかった': 194,
#  '分かりやすかった': 195,
#  '理解しやすかった': 194,
#  '指摘内容の把握を流暢に': 191,
#  '把握は楽': 190,
#  '難しかった': 188}

# %%
s.columns[0]
# Out:
# '好み1'

# %%
for i in range(20):
    print(pd.concat([s1.iloc[:,i], s2.iloc[:,i], s3.iloc[:,i], s4.iloc[:,i], s5.iloc[:,i]], axis=1))
# Out:
#      好み1  好み2  好み3  好み4  好み5
# 0      1    3    3    3    3
# 1      3    3    3    3    3
# 2      1    1    1    2    4
# 3      3    3    4    3    4
# 4      1    4    4    3    5
# ..   ...  ...  ...  ...  ...
# 799    3    2    3    3    3
# 800    1    2    3    3    3
# 801    5    5    5    5    5
# 802    1    4    3    4    4
# 803    1    3    3    3    3
#
# [804 rows x 5 columns]
#      不快1  不快2  不快3  不快4  不快5
# 0      3    3    5    4    4
# 1      3    3    3    3    3
# 2      5    5    4    3    1
# 3      3    4    4    4    4
# 4      1    5    5    5    5
# ..   ...  ...  ...  ...  ...
# 799    5    5    5    5    5
# 800    5    3    4    3    3
# 801    1    1    1    1    1
# 802    5    5    5    4    4
# 803    5    4    5    5    5
#
# [804 rows x 5 columns]
#      個人的に好き1  個人的に好き2  個人的に好き3  個人的に好き4  個人的に好き5
# 0          2        3        3        3        2
# 1          3        3        3        3        3
# ...

# %%
s1[['好み1']] + s2[['好み2']] + s3[['好み3']] + s4[['好み4']] + s5[['好み5']]

pd.concat([df1, df2, df3, df4, df5], axis=0)
# Out:
#      好み1  好み2  好み3  好み4  好み5
# 0    NaN  NaN  NaN  NaN  NaN
# 1    NaN  NaN  NaN  NaN  NaN
# 2    NaN  NaN  NaN  NaN  NaN
# 3    NaN  NaN  NaN  NaN  NaN
# 4    NaN  NaN  NaN  NaN  NaN
# ..   ...  ...  ...  ...  ...
# 799  NaN  NaN  NaN  NaN  NaN
# 800  NaN  NaN  NaN  NaN  NaN
# 801  NaN  NaN  NaN  NaN  NaN
# 802  NaN  NaN  NaN  NaN  NaN
# 803  NaN  NaN  NaN  NaN  NaN
#
# [804 rows x 5 columns]

# %%
print(wb.sheetnames)

# %%
import pandas as pd

df1 = pd.read_excel('主観評価設問状態_origin.xlsx', sheet_name='Sheet1')
df1
df1['target'] = 1
df1

# %%
#df1の10,11,12列の値をに取得

df1[df1.columns[10:13]]

# %%
df1[df1.columns[10:13]] = 6 - df1[df1.columns[10:13]]
df1[df1.columns[10:13]]

# %%
df2 = pd.read_excel('主観評価設問状態_origin.xlsx', sheet_name='Sheet2')
df2

df2['target'] = 2

# %%
df2[df2.columns[10:13]] = 6 - df2[df2.columns[10:13]]
df2[df2.columns[10:13]]

# %%
df3 = pd.read_excel('主観評価設問状態_origin.xlsx', sheet_name='Sheet3')
df3

df3['target'] = 3

# %%
df3[df3.columns[10:13]] = 6 - df3[df3.columns[10:13]]
df3[df3.columns[10:13]]

# %%
df4 = pd.read_excel('主観評価設問状態_origin.xlsx', sheet_name='Sheet4')
df4

df4['target'] = 4

# %%
df4[df4.columns[10:13]] = 6 - df4[df4.columns[10:13]]
df4[df4.columns[10:13]]

# %%
df5 = pd.read_excel('主観評価設問状態_origin.xlsx', sheet_name='Sheet5')
df5

df5['target'] = 5

# %%
df5[df5.columns[10:13]] = 6 - df5[df5.columns[10:13]]
df5[df5.columns[10:13]]

# %%
df = pd.concat([df1, df2, df3, df4, df5],axis=1)
df

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# サンプルデータの作成（実際にはデータを読み込む）
# df = pd.read_csv('your_data.csv') # 実際のデータ読み込み

# サンプルデータの例
data = {
    'participant_id': list(range(1, 805)) * 5,
    'feedback_method': ['no_feedback'] * 804 + ['image_only'] * 804 + ['audio_only'] * 804 + ['image_audio'] * 804 + ['image_alert'] * 804,
    'Q1': np.random.randint(1, 6, 804 * 5),
    'Q2': np.random.randint(1, 6, 804 * 5),
    'Q3': np.random.randint(1, 6, 804 * 5),
    'Q4': np.random.randint(1, 6, 804 * 5),
    'Q5': np.random.randint(1, 6, 804 * 5),
    'Q6': np.random.randint(1, 6, 804 * 5),
    'Q7': np.random.randint(1, 6, 804 * 5),
    'Q8': np.random.randint(1, 6, 804 * 5),
    'Q9': np.random.randint(1, 6, 804 * 5),
    'Q10': np.random.randint(1, 6, 804 * 5),
    'Q11': np.random.randint(1, 6, 804 * 5),
    'Q12': np.random.randint(1, 6, 804 * 5),
    'Q13': np.random.randint(1, 6, 804 * 5),
    'Q14': np.random.randint(1, 6, 804 * 5),
    'Q15': np.random.randint(1, 6, 804 * 5),
    'Q16': np.random.randint(1, 6, 804 * 5),
    'Q17': np.random.randint(1, 6, 804 * 5),
    'Q18': np.random.randint(1, 6, 804 * 5),
    'Q19': np.random.randint(1, 6, 804 * 5),
    'Q20': np.random.randint(1, 6, 804 * 5),
}

data

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# サンプルデータの作成（実際にはデータを読み込む）
# df = pd.read_csv('your_data.csv') # 実際のデータ読み込み

# サンプルデータの例
data = {
    'Q1': np.random.randint(1, 6, 804),
    'Q2': np.random.randint(1, 6, 804),
    'Q3': np.random.randint(1, 6, 804),
    'Q4': np.random.randint(1, 6, 804),
    'Q5': np.random.randint(1, 6, 804),
    'Q6': np.random.randint(1, 6, 804),
    'Q7': np.random.randint(1, 6, 804),
    'Q8': np.random.randint(1, 6, 804),
    'Q9': np.random.randint(1, 6, 804),
    'Q10': np.random.randint(1, 6, 804),
    'Q11': np.random.randint(1, 6, 804),
    'Q12': np.random.randint(1, 6, 804),
    'Q13': np.random.randint(1, 6, 804),
    'Q14': np.random.randint(1, 6, 804),
    'Q15': np.random.randint(1, 6, 804),
    'Q16': np.random.randint(1, 6, 804),
    'Q17': np.random.randint(1, 6, 804),
    'Q18': np.random.randint(1, 6, 804),
    'Q19': np.random.randint(1, 6, 804),
    'Q20': np.random.randint(1, 6, 804),
    'target': ['no_feedback'] * 161 + ['image_only'] * 161 + ['audio_only'] * 161 + ['image_audio'] * 161 + ['image_alert'] * 160
}

df = pd.DataFrame(data)

# 長い形式にデータを変換
df_long = pd.melt(df, id_vars=['target'], value_vars=[f'Q{i}' for i in range(1, 21)], var_name='Question', value_name='Response')

# プロット
plt.figure(figsize=(15, 8))
sns.boxplot(x='Question', y='Response', hue='target', data=df_long)
plt.title('Feedback Responses for Each Question')
plt.xlabel('Question')
plt.ylabel('Response')
plt.legend(title='Feedback Method', bbox_to_anchor=(1.05, 1), loc='upper left')
plt.show()

# %%
#df1,df2,df3,df4,df5を結合
df = pd.concat([df1, df2, df3, df4, df5])
df.columns
df

# %%
df

# %%
#matplotlib-japanize
import matplotlib.pyplot as plt
import japanize_matplotlib

# %%
# 特徴量のリスト
features_group_1 = ['好み', '不快', '個人的に好き', 'なぜ危険なのか']

# プロットの作成
fig, axes = plt.subplots(2, 2, figsize=(20, 15))

# カラーパレットを指定
palette = sns.color_palette("husl", n_colors=df['target'].nunique())

for i, feature in enumerate(features_group_1):
    ax = axes[i // 2, i % 2]
    sns.countplot(data=df, x=feature, hue='target', palette=palette, ax=ax)
    ax.set_title(feature, fontsize=18)
    ax.set_xlabel('Value', fontsize=16)
    ax.set_ylabel('Count', fontsize=16)
    ax.legend(title='Target', fontsize=14)  # レジェンドを手動で追加

plt.tight_layout()
plt.show()

# %%
# 特徴量のリスト
features_group_2 = ['どのように改善したらよいか', 'なるほど', '自分には関係ない',
       '改善しようと思う']

# プロットの作成
fig, axes = plt.subplots(2, 2, figsize=(20, 15))

# カラーパレットを指定
palette = sns.color_palette("husl", n_colors=df['target'].nunique())

for i, feature in enumerate(features_group_2):
    ax = axes[i // 2, i % 2]
    sns.countplot(data=df, x=feature, hue='target', palette=palette, ax=ax)
    ax.set_title(feature, fontsize=18)
    ax.set_xlabel('Value', fontsize=16)
    ax.set_ylabel('Count', fontsize=16)
    ax.legend(title='Target', fontsize=14)  # レジェンドを手動で追加

plt.tight_layout()
plt.show()

# %%
# 特徴量のリスト
features_group_3 = ['これからは注意して運転しよう', '急ブレーキのたびに出たら不快', 'たまに出てきても問題ない',
       '何度も出てきたら煩わしく']

# プロットの作成
fig, axes = plt.subplots(2, 2, figsize=(20, 15))

# カラーパレットを指定
palette = sns.color_palette("husl", n_colors=df['target'].nunique())

for i, feature in enumerate(features_group_3):
    ax = axes[i // 2, i % 2]
    sns.countplot(data=df, x=feature, hue='target', palette=palette, ax=ax)
    ax.set_title(feature, fontsize=18)
    ax.set_xlabel('Value', fontsize=16)
    ax.set_ylabel('Count', fontsize=16)
    ax.legend(title='Target', fontsize=14)  # レジェンドを手動で追加

plt.tight_layout()
plt.show()

# %%
# 特徴量のリスト
features_group_4 = ['ブレーキに関する内容', '自分の運転に対する内容', '何の操作に対する指摘かよくわからなかった',
       '分かりやすかった']

# プロットの作成
fig, axes = plt.subplots(2, 2, figsize=(20, 15))

# カラーパレットを指定
palette = sns.color_palette("husl", n_colors=df['target'].nunique())

for i, feature in enumerate(features_group_4):
    ax = axes[i // 2, i % 2]
    sns.countplot(data=df, x=feature, hue='target', palette=palette, ax=ax)
    ax.set_title(feature, fontsize=18)
    ax.set_xlabel('Value', fontsize=16)
    ax.set_ylabel('Count', fontsize=16)
    ax.legend(title='Target', fontsize=14)  # レジェンドを手動で追加

plt.tight_layout()
plt.show()

# %%
# 特徴量のリスト

# 特徴量のリスト
features_group_5 = ['理解しやすかった', '指摘内容の把握を流暢に', '把握は楽', '難しかった']

# プロットの作成
fig, axes = plt.subplots(2, 2, figsize=(20, 15))

# カラーパレットを指定
palette = sns.color_palette("husl", n_colors=df['target'].nunique())

for i, feature in enumerate(features_group_5):
    ax = axes[i // 2, i % 2]
    sns.countplot(data=df, x=feature, hue='target', palette=palette, ax=ax)
    ax.set_title(feature, fontsize=18)
    ax.set_xlabel('Value', fontsize=16)
    ax.set_ylabel('Count', fontsize=16)
    ax.legend(title='Target', fontsize=14)  # レジェンドを手動で追加

plt.tight_layout()
plt.show()

# %%
#df1,df2,df3,df4,df5を読み込む
df1 = pd.read_excel('主観評価設問状態_origin.xlsx', sheet_name='Sheet1')
df2 = pd.read_excel('主観評価設問状態_origin.xlsx', sheet_name='Sheet2')
df3 = pd.read_excel('主観評価設問状態_origin.xlsx', sheet_name='Sheet3')
df4 = pd.read_excel('主観評価設問状態_origin.xlsx', sheet_name='Sheet4')
df5 = pd.read_excel('主観評価設問状態_origin.xlsx', sheet_name='Sheet5')

# #df1,df2,df3,df4,df5の値を足す
# df_sum = df1 + df2 + df3 + df4 + df5
# df_sum

# #df1,df2,df3,df4,df5の値を平均する
# df_mean = (df1 + df2 + df3 + df4 + df5) / 5
# df_mean

pd.concat([df1, df2, df3, df4, df5], axis=0)
# Out:
#      好み  不快  個人的に好き  なぜ危険なのか  どのように改善したらよいか  なるほど  自分には関係ない  改善しようと思う  \
# 0     1   3       2        1              1     1         3         3
# 1     3   3       3        3              3     3         3         3
# 2     1   5       1        1              5     1         5         1
# 3     3   3       3        1              5     1         1         1
# 4     1   1       1        1              1     1         1         1
# ..   ..  ..     ...      ...            ...   ...       ...       ...
# 799   3   5       3        5              5     5         5         5
# 800   3   3       1        5              5     5         5         4
# 801   5   1       5        5              1     5         1         5
# 802   4   4       4        5              5     5         5         5
# 803   3   5       3        4              5     4         5         4
#
#      これからは注意して運転しよう  急ブレーキのたびに出たら不快  たまに出てきても問題ない  何度も出てきたら煩わしく  ブレーキに関する内容  \
# ...

# %%
#20列目までの値を取得

#df1~df5ごとに804人分をプロット

# %%
#df1,df2,df3,df4,df5を読み込む
df1 = pd.read_excel('主観評価設問状態_origin.xlsx', sheet_name='Sheet1')
df2 = pd.read_excel('主観評価設問状態_origin.xlsx', sheet_name='Sheet2')
df3 = pd.read_excel('主観評価設問状態_origin.xlsx', sheet_name='Sheet3')
df4 = pd.read_excel('主観評価設問状態_origin.xlsx', sheet_name='Sheet4')
df5 = pd.read_excel('主観評価設問状態_origin.xlsx', sheet_name='Sheet5')

# %%
new_column_names1 = [col + '1' for col in df1.columns]
new_column_names1
df1.columns = new_column_names1

new_column_names2 = [col + '2' for col in df2.columns]
new_column_names2
df2.columns = new_column_names2

new_column_names3 = [col + '3' for col in df3.columns]
new_column_names3
df3.columns = new_column_names3

new_column_names4 = [col + '4' for col in df4.columns]
new_column_names4
df4.columns = new_column_names4

new_column_names5 = [col + '5' for col in df5.columns]
new_column_names5
df5.columns = new_column_names5

# %%
#df1,df2,df3,df4,df5をaxis=1で結合

df_out = pd.concat([df1,df2,df3,df4,df5],axis=1)
df_out

# %%
df_out.to_excel('主観評価設問状態_origin_出力100.xlsx', index=False)

# %%
df.to_excel('主観評価設問状態_origin_結合.xlsx', index=False)

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
# 各提示に対するスコアの標準化
scaler = StandardScaler()
data_scaled = scaler.fit_transform(df)

data_scaled.shape

# %%
# K-meansクラスタリング
kmeans = KMeans(n_clusters=5, random_state=42)
df['Cluster'] = kmeans.fit_predict(data_scaled)

# クラスタごとの中心点（平均値）の計算
cluster_centers = pd.DataFrame(scaler.inverse_transform(kmeans.cluster_centers_), columns=df.columns[:-1])
# cluster_labels = cluster_centers.idxmax(axis=1)

# クラスタに基づいたラベル付け
# df['Label'] = df['Cluster'].map(lambda x: cluster_labels[x])

# ラベル付け結果の確認
print(df.head())

# %%
data_scaled.shape

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# PCAで2次元に変換
pca = PCA(n_components=2)
pca_result = pca.fit_transform(data_scaled)

# クラスタの可視化
plt.figure(figsize=(10, 7))
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=df['Cluster'], cmap='viridis', s=50, alpha=0.7)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-means Clustering with PCA')
plt.colorbar(label='Cluster')
plt.show()

# %%
# クラスタの可視化
plt.figure(figsize=(10, 7))
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=df['target'], cmap='viridis', s=50, alpha=0.7)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-means Clustering with PCA')
plt.colorbar(label='Cluster')
plt.show()

# %%
df['Cluster'].value_counts()

# %%
df['target'].value_counts()

# %%
#PCAで特徴抽出

import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# PCAで2次元に変換
pca = PCA(n_components=2)
pca_result = pca.fit_transform(data_scaled)

# クラスタの可視化
plt.figure(figsize=(10, 7))
plt.scatter(pca_result[:, 0], pca_result[:, 1], c=df['target'], cmap='viridis', s=50, alpha=0.7)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-means Clustering with PCA')
plt.colorbar(label='Cluster')
plt.show()

# クラスタの可視化
plt.figure(figsize=(10, 7))

plt.scatter(pca_result[:, 0], pca_result[:, 1], c=df['Cluster'], cmap='viridis', s=50, alpha=0.7)
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('K-means Clustering with PCA')
plt.colorbar(label='Cluster')
plt.show()

# %%
#tsneで特徴抽出
from sklearn.manifold import TSNE

# t-SNEで2次元に変換
tsne = TSNE(n_components=2, random_state=42)
tsne_result = tsne.fit_transform(data_scaled)

# クラスタの可視化
plt.figure(figsize=(10, 7))
plt.scatter(tsne_result[:, 0], tsne_result[:, 1], c=df['target'], cmap='viridis', s=50, alpha=0.7)
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.title('K-means Clustering with t-SNE')
plt.colorbar(label='Cluster')
plt.show()

# クラスタの可視化
plt.figure(figsize=(10, 7))
plt.scatter(tsne_result[:, 0], tsne_result[:, 1], c=df['Cluster'], cmap='viridis', s=50, alpha=0.7)
plt.xlabel('t-SNE 1')
plt.ylabel('t-SNE 2')
plt.title('K-means Clustering with t-SNE')
plt.colorbar(label='Cluster')
plt.show()

#クラスタごとの平均値
cluster_centers = pd.DataFrame(scaler.inverse_transform(kmeans.cluster_centers_), columns=df.columns[:-1])
cluster_centers

# %%
# df.to_excel('主観評価設問状態_origin_cluster.xlsx', index=False)

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler



# 各提示に対するスコアの標準化
scaler = StandardScaler()
data_scaled = scaler.fit_transform(df.iloc[:, :-1])

# K-meansクラスタリング
kmeans = KMeans(n_clusters=5, random_state=42)
df['Cluster'] = kmeans.fit_predict(data_scaled)

# クラスタごとの中心点（平均値）の計算
cluster_centers = pd.DataFrame(scaler.inverse_transform(kmeans.cluster_centers_), columns=df.columns[:-2])
cluster_labels = cluster_centers.idxmax(axis=1)

# クラスタに基づいたラベル付け
df['Label'] = df['Cluster'].map(cluster_labels)

# ラベル付け結果の確認
print(df.head())

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import Input, Dense
from tensorflow.keras.models import Model
from sklearn.preprocessing import StandardScaler

# データの標準化
scaler = StandardScaler()
data_scaled = scaler.fit_transform(df5)

# Autoencoderの定義
input_dim = data_scaled.shape[1]
encoding_dim = 3  # 次元圧縮後の次元数

input_layer = Input(shape=(input_dim,))
encoded = Dense(encoding_dim, activation='relu')(input_layer)
decoded = Dense(input_dim, activation='sigmoid')(encoded)

# Autoencoderモデル
autoencoder = Model(input_layer, decoded)

# Encoderモデル
encoder = Model(input_layer, encoded)

# Decoderモデル
encoded_input = Input(shape=(encoding_dim,))
decoder_layer = autoencoder.layers[-1]
decoder = Model(encoded_input, decoder_layer(encoded_input))

# モデルのコンパイル
autoencoder.compile(optimizer='adam', loss='mean_squared_error')

# モデルの学習
autoencoder.fit(data_scaled, data_scaled,
                epochs=50,
                batch_size=32,
                shuffle=True,
                validation_split=0.2)

# データの次元圧縮
encoded_data = encoder.predict(data_scaled)

# 次元圧縮結果の表示
print(encoded_data)

# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

# PCAで2次元に変換
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(encoded_data)

# 2次元プロット
plt.scatter(reduced_data[:, 0], reduced_data[:, 1])
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.title('2D PCA of Encoded Data')
plt.show()

# %%
#df5を主成分分析
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
#japanize_matplotlib
import japanize_matplotlib

import seaborn as sns

pca = PCA()
pca.fit(df1)

# データを主成分空間に写像
feature = pca.transform(df1)

#寄与率と累積寄与率の計算
ev_ratio = pca.explained_variance_ratio_
cum_ev_ratio = ev_ratio.cumsum()

#主成分負荷量を取得
loadings = pca.components_

#結果の表示
print("各主成分の寄与率:")
for i, ev in enumerate(ev_ratio):
    print(f"PC{i+1}: {ev:.4f}")

print("\n各主成分の累積寄与率:")
for i, cev in enumerate(cum_ev_ratio):
    print(f"PC{i+1}: {cev:.4f}")

# 主成分得点のプロット
plt.figure(figsize=(8, 6))



# 第一主成分と第二主成分でプロットする
plt.figure()
plt.scatter(feature[:, 0], feature[:, 1], alpha=0.8)
plt.title('Principal component analysis')
plt.xlabel('The first principal component')
plt.ylabel('The second principal component')
plt.grid()
plt.show()

# %%
# 主成分得点 https://qiita.com/maskot1977/items/082557fcda78c4cdb41f
pd.DataFrame(feature, columns=["PC{}".format(x + 1) for x in range(len(df1.columns))])

# %%
from pandas import plotting 
plotting.scatter_matrix(pd.DataFrame(feature, 
                        columns=["PC{}".format(x + 1) for x in range(len(df5.columns))]), 
                        figsize=(8, 8), c=list(df5.iloc[:, 0]), alpha=0.5) 
plt.show()

# %%
# 寄与率
pd.DataFrame(pca.explained_variance_ratio_, index=["PC{}".format(x + 1) for x in range(len(df5.columns))])

# %%
# 累積寄与率を図示する
import matplotlib.ticker as ticker
plt.gca().get_xaxis().set_major_locator(ticker.MaxNLocator(integer=True))
plt.plot([0] + list( np.cumsum(pca.explained_variance_ratio_)), "-o")
plt.xlabel("Number of principal components")
plt.ylabel("Cumulative contribution rate")
plt.grid()
plt.show()

# %%
# PCA の固有値
pd.DataFrame(pca.explained_variance_, index=["PC{}".format(x + 1) for x in range(len(df1.columns))])

# %%
#df5を主成分分析 (主成分数3)
from sklearn.decomposition import PCA
import matplotlib.pyplot as plt
import seaborn as sns

pca = PCA(n_components=3)
pca.fit(df5)

# データを主成分空間に写像
feature = pca.transform(df5)

#寄与率と累積寄与率の計算
ev_ratio = pca.explained_variance_ratio_
cum_ev_ratio = ev_ratio.cumsum()

#主成分負荷量を取得
loadings = pca.components_

#結果の表示
print("各主成分の寄与率:")
for i, ev in enumerate(ev_ratio):
    print(f"PC{i+1}: {ev:.4f}")

print("\n各主成分の累積寄与率:")
for i, cev in enumerate(cum_ev_ratio):
    print(f"PC{i+1}: {cev:.4f}")

# 主成分得点のプロット
plt.figure(figsize=(8, 6))

# 第一主成分と第二主成分でプロットする
plt.figure()
plt.scatter(feature[:, 0], feature[:, 1], alpha=0.8)
plt.title('Principal component analysis')
plt.xlabel('The first principal component')
plt.ylabel('The second principal component')
plt.grid()
plt.show()

#主成分負荷量のプロット
plt.figure()
plt.matshow(loadings, cmap='coolwarm')
plt.colorbar()
plt.xticks(range(len(df5.columns)), df5.columns, rotation=90)
plt.show()
