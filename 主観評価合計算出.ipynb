# %%
import pandas as pd
import numpy as np
from factor_analyzer.utils import covariance_to_correlation
import graphviz
import semopy
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_image = pd.read_csv("image.csv", encoding='shift_jis')
df_image
# Out:
#        x       d1      d2      d3       d4       d5        w1        w2  \
# 0      1   6.2937  1.9398  6.7618  3.07992  5.72156  36.96507  25.87807
# 1      2  11.0338  6.1047  7.2883  7.54295  9.90751  25.40064  16.89495
# 2      3   7.1932  2.1034  4.9684  5.66562  8.38533  29.94836  20.88529
# 3      4   7.8981 -0.9757  4.2858  3.84009  4.87743  26.87720  18.93591
# 4      5   9.7256  0.0349  7.1680  3.90703  6.30194  43.20713  28.51156
# ..   ...      ...     ...     ...      ...      ...       ...       ...
# 799  800   7.5822  0.1201  6.5722  3.32963  4.75933  22.04394  17.21857
# 800  801   5.6149 -0.7314  1.6795  3.74132  5.60217  29.58012  15.73032
# 801  802   6.0455  2.0958  3.8635  4.97563  5.69270  28.18144  19.74430
# 802  803   8.6738 -0.4216  1.4291  4.27503  5.49286  31.06191  21.50243
# 803  804   3.5565 -0.0380  3.4472  2.81113  3.50357  30.25131  18.98164
#
#            w3        w4  ...  c4  c5  c6  p        s1        s2        s3  \
# ...

# %%
df_image_s = df_image[['s1', 's2', 's3', 's4', 's5', 's6']].sum(axis=1).round(4)
df_image_s
# Out:
# 0      18.9333
# 1      18.0000
# 2      14.8000
# 3      20.2667
# 4      26.4667
#         ...
# 799    25.8000
# 800    24.3333
# 801    19.4000
# 802    27.6667
# 803    21.6000
# Length: 804, dtype: float64

# %%
df_anounce = pd.read_csv("announce.csv",encoding='shift_jis')
df_anounce
# Out:
#        x       d1      d2      d3       d4       d5        w1        w2  \
# 0      1   6.2937  1.9398  6.7618  3.07992  5.72156  36.96507  25.87807
# 1      2  11.0338  6.1047  7.2883  7.54295  9.90751  25.40064  16.89495
# 2      3   7.1932  2.1034  4.9684  5.66562  8.38533  29.94836  20.88529
# 3      4   7.8981 -0.9757  4.2858  3.84009  4.87743  26.87720  18.93591
# 4      5   9.7256  0.0349  7.1680  3.90703  6.30194  43.20713  28.51156
# ..   ...      ...     ...     ...      ...      ...       ...       ...
# 799  800   7.5822  0.1201  6.5722  3.32963  4.75933  22.04394  17.21857
# 800  801   5.6149 -0.7314  1.6795  3.74132  5.60217  29.58012  15.73032
# 801  802   6.0455  2.0958  3.8635  4.97563  5.69270  28.18144  19.74430
# 802  803   8.6738 -0.4216  1.4291  4.27503  5.49286  31.06191  21.50243
# 803  804   3.5565 -0.0380  3.4472  2.81113  3.50357  30.25131  18.98164
#
#            w3        w4  ...  c4  c5  c6  p        s1        s2        s3  \
# ...

# %%
df_anounce_s = df_anounce[['s1', 's2', 's3', 's4', 's5', 's6']].sum(axis=1).round(4)
df_anounce_s
# Out:
# 0      22.2000
# 1      18.0000
# 2      16.4000
# 3      23.4000
# 4      27.4667
#         ...
# 799    27.0000
# 800    25.6667
# 801    21.2000
# 802    25.4667
# 803    25.5333
# Length: 804, dtype: float64

# %%
df_none = pd.read_csv("none.csv",encoding='shift_jis')
df_none
# Out:
#        x       d1      d2      d3       d4       d5        w1        w2  \
# 0      1   6.2937  1.9398  6.7618  3.07992  5.72156  36.96507  25.87807
# 1      2  11.0338  6.1047  7.2883  7.54295  9.90751  25.40064  16.89495
# 2      3   7.1932  2.1034  4.9684  5.66562  8.38533  29.94836  20.88529
# 3      4   7.8981 -0.9757  4.2858  3.84009  4.87743  26.87720  18.93591
# 4      5   9.7256  0.0349  7.1680  3.90703  6.30194  43.20713  28.51156
# ..   ...      ...     ...     ...      ...      ...       ...       ...
# 799  800   7.5822  0.1201  6.5722  3.32963  4.75933  22.04394  17.21857
# 800  801   5.6149 -0.7314  1.6795  3.74132  5.60217  29.58012  15.73032
# 801  802   6.0455  2.0958  3.8635  4.97563  5.69270  28.18144  19.74430
# 802  803   8.6738 -0.4216  1.4291  4.27503  5.49286  31.06191  21.50243
# 803  804   3.5565 -0.0380  3.4472  2.81113  3.50357  30.25131  18.98164
#
#            w3        w4  ...  c4  c5  c6  p        s1        s2        s3  \
# ...

# %%
df_none_s = df_none[['s1', 's2', 's3', 's4', 's5', 's6']].sum(axis=1).round(4)
df_none_s
# Out:
# 0       9.6667
# 1      18.0000
# 2      14.8000
# 3      13.6667
# 4       8.6667
#         ...
# 799    12.0000
# 800    14.8000
# 801    20.2667
# 802    11.0667
# 803    12.0000
# Length: 804, dtype: float64

# %%
df_image_announce = pd.read_csv("image_announce.csv",encoding='shift_jis')
df_image_announce
# Out:
#        x       d1      d2      d3       d4       d5        w1        w2  \
# 0      1   6.2937  1.9398  6.7618  3.07992  5.72156  36.96507  25.87807
# 1      2  11.0338  6.1047  7.2883  7.54295  9.90751  25.40064  16.89495
# 2      3   7.1932  2.1034  4.9684  5.66562  8.38533  29.94836  20.88529
# 3      4   7.8981 -0.9757  4.2858  3.84009  4.87743  26.87720  18.93591
# 4      5   9.7256  0.0349  7.1680  3.90703  6.30194  43.20713  28.51156
# ..   ...      ...     ...     ...      ...      ...       ...       ...
# 799  800   7.5822  0.1201  6.5722  3.32963  4.75933  22.04394  17.21857
# 800  801   5.6149 -0.7314  1.6795  3.74132  5.60217  29.58012  15.73032
# 801  802   6.0455  2.0958  3.8635  4.97563  5.69270  28.18144  19.74430
# 802  803   8.6738 -0.4216  1.4291  4.27503  5.49286  31.06191  21.50243
# 803  804   3.5565 -0.0380  3.4472  2.81113  3.50357  30.25131  18.98164
#
#            w3        w4  ...  c4  c5  c6  p        s1        s2        s3  \
# ...

# %%
df_image_announce_s = df_image_announce[['s1', 's2', 's3', 's4', 's5', 's6']].sum(axis=1).round(4)
df_image_announce_s
# Out:
# 0      21.0000
# 1      18.0000
# 2      20.5333
# 3      22.7333
# 4      28.1333
#         ...
# 799    27.0000
# 800    24.2000
# 801    21.2000
# 802    26.0000
# 803    25.0667
# Length: 804, dtype: float64

# %%
df_image_sound = pd.read_csv("sound.csv",encoding='shift_jis')
df_image_sound
# Out:
#        x       d1      d2      d3       d4       d5        w1        w2  \
# 0      1   6.2937  1.9398  6.7618  3.07992  5.72156  36.96507  25.87807
# 1      2  11.0338  6.1047  7.2883  7.54295  9.90751  25.40064  16.89495
# 2      3   7.1932  2.1034  4.9684  5.66562  8.38533  29.94836  20.88529
# 3      4   7.8981 -0.9757  4.2858  3.84009  4.87743  26.87720  18.93591
# 4      5   9.7256  0.0349  7.1680  3.90703  6.30194  43.20713  28.51156
# ..   ...      ...     ...     ...      ...      ...       ...       ...
# 799  800   7.5822  0.1201  6.5722  3.32963  4.75933  22.04394  17.21857
# 800  801   5.6149 -0.7314  1.6795  3.74132  5.60217  29.58012  15.73032
# 801  802   6.0455  2.0958  3.8635  4.97563  5.69270  28.18144  19.74430
# 802  803   8.6738 -0.4216  1.4291  4.27503  5.49286  31.06191  21.50243
# 803  804   3.5565 -0.0380  3.4472  2.81113  3.50357  30.25131  18.98164
#
#            w3        w4  ...  c4  c5  c6  p        s1        s2        s3  \
# ...

# %%
df_image_sound[10:12]
# Out:
#      x       d1      d2      d3       d4       d5        w1        w2  \
# 10  11  11.2152 -0.0281  7.2976  2.97328  5.82015  41.47728  27.95262
# 11  12   9.4364  0.1152  6.7718  4.23545  5.70141  28.60618  25.04275
#
#           w3        w4  ...  c4  c5  c6  p        s1        s2        s3  \
# 10  24.61538  25.81867  ...  27  24  18  2  4.333333  4.333333  4.333333
# 11  15.88711  17.95078  ...  19  25  19  5  3.666667  2.333333  3.333333
#
#           s4   s5        s6
# 10  2.333333  4.0  4.333333
# 11  4.333333  3.8  2.333333
#
# [2 rows x 24 columns]

# %%
df_image_sound_s = df_image_sound[['s1', 's2', 's3', 's4', 's5', 's6']].sum(axis=1).round(4)
df_image_sound_s
# Out:
# 0      22.0000
# 1      18.0000
# 2      15.7333
# 3      19.7333
# 4      25.0667
#         ...
# 799    27.0000
# 800    22.6667
# 801    21.2000
# 802    24.1333
# 803    25.4000
# Length: 804, dtype: float64

# %%
df_image[10:12]
# Out:
#      x       d1      d2      d3       d4       d5        w1        w2  \
# 10  11  11.2152 -0.0281  7.2976  2.97328  5.82015  41.47728  27.95262
# 11  12   9.4364  0.1152  6.7718  4.23545  5.70141  28.60618  25.04275
#
#           w3        w4  ...  c4  c5  c6  p        s1        s2        s3  \
# 10  24.61538  25.81867  ...  27  24  18  2  5.000000  5.000000  5.000000
# 11  15.88711  17.95078  ...  19  25  19  5  3.666667  3.666667  4.333333
#
#           s4   s5   s6
# 10  2.333333  5.0  5.0
# 11  4.333333  3.8  3.0
#
# [2 rows x 24 columns]

# %%
df_all = pd.concat([df_none[['x', 'd1', 'd2', 'd3', 'd4', 'd5', 'w1', 'w2', 'w3', 'w4', 'w5', 'c1',
       'c2', 'c3', 'c4', 'c5', 'c6', 'p']],df_none_s,df_image_s,df_anounce_s,df_image_sound_s,df_image_announce_s],axis=1)
df_all.columns = ['x', 'd1', 'd2', 'd3', 'd4', 'd5', 'w1', 'w2', 'w3', 'w4', 'w5', 'c1',
       'c2', 'c3', 'c4', 'c5', 'c6', 'p','none_s','image_s','announce_s','image_sound_s','image_announce_s']
df_all
# Out:
#        x       d1      d2      d3       d4       d5        w1        w2  \
# 0      1   6.2937  1.9398  6.7618  3.07992  5.72156  36.96507  25.87807
# 1      2  11.0338  6.1047  7.2883  7.54295  9.90751  25.40064  16.89495
# 2      3   7.1932  2.1034  4.9684  5.66562  8.38533  29.94836  20.88529
# 3      4   7.8981 -0.9757  4.2858  3.84009  4.87743  26.87720  18.93591
# 4      5   9.7256  0.0349  7.1680  3.90703  6.30194  43.20713  28.51156
# ..   ...      ...     ...     ...      ...      ...       ...       ...
# 799  800   7.5822  0.1201  6.5722  3.32963  4.75933  22.04394  17.21857
# 800  801   5.6149 -0.7314  1.6795  3.74132  5.60217  29.58012  15.73032
# 801  802   6.0455  2.0958  3.8635  4.97563  5.69270  28.18144  19.74430
# 802  803   8.6738 -0.4216  1.4291  4.27503  5.49286  31.06191  21.50243
# 803  804   3.5565 -0.0380  3.4472  2.81113  3.50357  30.25131  18.98164
#
#            w3        w4  ...  c3  c4  c5  c6  p   none_s  image_s  announce_s  \
# ...

# %%
df_all.to_csv('all_sum.csv')

# %%
# file_base_name = "image"
# file_extension = ".csv"
# file_name = file_base_name + file_extension

# # df_image = pd.read_csv(file_name, encoding='shift_jis')

# df_name = f"df_{file_base_name}"

# # データフレームを格納する辞書
# data_frames = {}

# # 辞書にデータフレームを格納
# data_frames[df_name] = pd.read_csv(file_name, encoding='shift_jis')

# df_s[] = data_frames[df_name][['s1', 's2', 's3', 's4', 's5', 's6']].mean(axis=1)
