# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
#matplotlib 日本語化対応
import japanize_matplotlib

# %%
df_all = pd.read_csv('all.csv')

#df_all の　30~36行目を表示
df_all[30:36]
# Out:
#     Unnamed: 0   x      d1      d2      d3       d4       d5        w1  \
# 30          30  31  9.5315  0.4201  6.8229  2.11463  5.86608  42.72710
# 31          31  32  4.1359  0.1694  1.3210  2.93938  4.32040  22.57982
# 32          32  33  3.0471 -0.8066  3.4866  2.54958  3.97575  17.50018
# 33          33  34  7.4574  5.5953  6.2773  7.03843  8.18501  18.34553
# 34          34  35  6.6637  1.4400  4.3149  4.62139  5.41970  20.41180
# 35          35  36  1.0075  1.3439  2.5615  3.53970  4.28851  26.23617
#
#           w2        w3  ...  c3  c4  c5  c6  p  none_s  image_s  announce_s  \
# 30  26.17389  26.36388  ...  28  17  23  25  5  2.4667   4.1333      5.0000
# 31  16.88658  12.05032  ...  22  13  11  12  4  3.0000   3.3889      4.2111
# 32  11.13775  10.55516  ...  21  23  20  19  3  3.0000   3.7222      3.6667
# 33  11.31914  12.16216  ...  12  28  19  18  5  3.0444   3.7111      3.3000
# 34  13.70617  14.08719  ...  19  19  11   6  2  2.9889   2.7333      3.0556
# 35  18.92944  17.92372  ...  30  28  11  11  4  3.2667   3.4556      3.2444
#
#     image_sound_s  image_announce_s
# 30         4.0556            4.0556
# 31         3.0889            3.8444
# 32         3.6667            3.7222
# 33         3.3000            3.1778
# 34         2.9111            2.8000
# 35         2.6111            3.3222
#
# [6 rows x 24 columns]

# %%
#none_s,image_s,announce_s,image_sound_s,image_announce_s
df_all[['none_s','image_s','announce_s','image_sound_s','image_announce_s']].head()
# Out:
#    none_s  image_s  announce_s  image_sound_s  image_announce_s
# 0  1.6111   3.1556      3.7000         3.6667            3.5000
# 1  3.0000   3.0000      3.0000         3.0000            3.0000
# 2  2.4667   2.4667      2.7333         2.6222            3.4222
# 3  2.2778   3.3778      3.9000         3.2889            3.7889
# 4  1.4444   4.4111      4.5778         4.1778            4.6889

# %%
df_all.columns
# Out:
# Index(['Unnamed: 0', 'x', 'd1', 'd2', 'd3', 'd4', 'd5', 'w1', 'w2', 'w3', 'w4',
#        'w5', 'c1', 'c2', 'c3', 'c4', 'c5', 'c6', 'p', 'none_s', 'image_s',
#        'announce_s', 'image_sound_s', 'image_announce_s'],
#       dtype='object')

# %%
new_column_names = {'none_s': '提示なし','image_s': '画像のみ', 'announce_s': '音声のみ','image_sound_s': '画像+報知音', 'image_announce_s': '画像+音声'}

df_all = df_all.rename(columns=new_column_names)

# %%
# df_all_s = df_all[['提示なし', '画像のみ', '音声のみ', '画像+報知音', '画像+音声']]

df_all_s = pd.read_csv('主観評価設問状態_origin_mean_drop0808.csv')

new_column_names = {'0': '提示なし','1': '画像のみ', '2': '音声のみ','3': '画像+報知音', '4': '画像+音声'}

df_all_s = df_all_s.rename(columns=new_column_names)
df_all_s[6:13]
# Out:
#     Unnamed: 0  提示なし  画像のみ  音声のみ  画像+報知音  画像+音声
# 6            6  3.00  3.00   3.0    3.00   3.00
# 7            7  3.20  3.05   3.2    3.05   3.15
# 8            8  2.75  3.00   2.9    3.00   3.40
# 9            9  3.00  2.70   3.1    2.60   3.20
# 10          10  2.00  4.60   4.5    4.05   4.35
# 11          11  2.60  3.50   3.9    3.05   3.80
# 12          12  2.40  3.50   3.4    3.50   3.35

# %%
df_all_in = df_all[['安全運転特性', '不安定な運転特性', '心配性特性', 'ステイタス特性', '事前準備特性',
       '道路状況把握負担', '心身状況負担', '運転ペース阻害負担', '車環境負担', '視野環境負担', '写真タイプ',
       '三次元映像タイプ', '言語映像タイプ', '言語抽象タイプ', '聴覚言語タイプ', '聴覚&音タイプ', '行動変容フェーズ']]
df_all_in
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df_all_in = df_all[['安全運転特性', '不安定な運転特性', '心配性特性', 'ステイタス特性', '事前準備特性',
#       2        '道路状況把握負担', '心身状況負担', '運転ペース阻害負担', '車環境負担', '視野環境負担', '写真タイプ',
#       3        '三次元映像タイプ', '言語映像タイプ', '言語抽象タイプ', '聴覚言語タイプ', '聴覚&音タイプ', '行動変容フェーズ']]
#       4 df_all_in
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
#    6118 if isinstance(key, Index):
#    6119     # GH 42790 - Preserve name from an Index
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6176, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6174     if use_interval_msg:
#    6175         key = list(key)
# -> 6176     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6178 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6179 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['安全運転特性', '不安定な運転特性', '心配性特性', 'ステイタス特性', '事前準備特性', '道路状況把握負担',\n       '心身状況負担', '運転ペース阻害負担', '車環境負担', '視野環境負担', '写真タイプ', '三次元映像タイプ',\n       '言語映像タイプ', '言語抽象タイプ', '聴覚言語タイプ', '聴覚&音タイプ', '行動変容フェーズ'],\n      dtype='object')] are in the [columns]"

# %%
#t-sne
#空間が分離できているかどうかの確認
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
tsne.fit(df_all_in)
x = tsne.fit_transform(df_all_in)
plt.scatter(x[:, 0], x[:, 1])
plt.colorbar()
plt.show()

#k-means
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=2, random_state=0)
kmeans.fit(df_all_in)
df_all['cluster'] = kmeans.labels_

#クラスタリング結果の可視化
plt.scatter(x[:, 0], x[:, 1], c=df_all['cluster'])
plt.colorbar()
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df_all_drop_exp = pd.read_csv('all_drop_exp_re.csv')
df_all_drop_exp
# Out:
#      Unnamed: 0       d1      d2      d3       d4       d5        w1  \
# 0             0   6.2937  1.9398  6.7618  3.07992  5.72156  36.96507
# 1             2   7.1932  2.1034  4.9684  5.66562  8.38533  29.94836
# 2             3   7.8981 -0.9757  4.2858  3.84009  4.87743  26.87720
# 3             4   9.7256  0.0349  7.1680  3.90703  6.30194  43.20713
# 4             5   4.9113  1.4880  3.0357  4.70687  6.26354  26.34567
# ..          ...      ...     ...     ...      ...      ...       ...
# 635         796   7.0463 -1.1722  4.3281  2.71297  7.12817  20.17931
# 636         797   8.5748 -1.1702  4.7669  4.87733  7.84963  27.71802
# 637         798  10.2154 -1.1652  5.1767  2.77794  4.07748  21.64954
# 638         802   8.6738 -0.4216  1.4291  4.27503  5.49286  31.06191
# 639         803   3.5565 -0.0380  3.4472  2.81113  3.50357  30.25131
#
#            w2        w3        w4  ...  c3  c4  c5  c6  p  none_s  image_s  \
# 0    25.87807  21.29791  21.00362  ...  29  21  10   6  3    1.75     3.10
# 1    20.88529  19.59672  20.50303  ...  18  16  18  15  4    2.40     2.40
# 2    18.93591  16.00807  17.58007  ...  28  16  17  11  4    2.15     3.40
# 3    28.51156  24.68393  25.27235  ...  23  24  24  23  5    1.80     4.05
# 4    23.30003  23.58674  17.89807  ...  16  11  22  22  3    2.50     3.45
# ..        ...       ...       ...  ...  ..  ..  ..  .. ..     ...      ...
# 635  10.61594  10.69781   8.36414  ...  26  31  21  13  5    2.25     2.50
# 636  19.01448  16.56406  16.81861  ...  30  14  14  10  5    2.50     3.10
# 637  14.42384  14.39132  14.72991  ...  36  13  21  29  2    2.95     2.90
# 638  21.50243  19.40287  18.43385  ...  28  26  17   6  4    2.20     4.25
# 639  18.98164  19.62766  17.88559  ...  22  16  22  10  3    2.10     3.50
#
#      announce_s  image_sound_s  image_announce_s
# 0          3.55           3.60              3.55
# 1          2.70           2.60              3.50
# 2          3.85           3.30              3.55
# 3          4.20           3.80              4.70
# 4          3.20           2.65              3.70
# ..          ...            ...               ...
# 635        3.80           2.30              3.35
# 636        3.90           3.20              3.80
# 637        2.80           2.90              2.85
# 638        4.20           3.90              4.30
# 639        4.05           4.05              4.10
#
# [640 rows x 23 columns]

# %%
df_all_drop_exp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 640 entries, 0 to 639
# Data columns (total 23 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        640 non-null    int64
#  1   d1                640 non-null    float64
#  2   d2                640 non-null    float64
#  3   d3                640 non-null    float64
#  4   d4                640 non-null    float64
#  5   d5                640 non-null    float64
#  6   w1                640 non-null    float64
#  7   w2                640 non-null    float64
#  8   w3                640 non-null    float64
#  9   w4                640 non-null    float64
#  10  w5                640 non-null    float64
#  11  c1                640 non-null    int64
#  12  c2                640 non-null    int64
#  13  c3                640 non-null    int64
#  14  c4                640 non-null    int64
#  15  c5                640 non-null    int64
#  16  c6                640 non-null    int64
#  17  p                 640 non-null    int64
#  18  none_s            640 non-null    float64
#  19  image_s           640 non-null    float64
#  20  announce_s        640 non-null    float64
#  21  image_sound_s     640 non-null    float64
#  22  image_announce_s  640 non-null    float64
# dtypes: float64(15), int64(8)
# memory usage: 115.1 KB

# %%
new_column_names = {'gender':'性別','age':'年齢','d1': '安全運転特性', 'd2': '不安定な運転特性','d3': '心配性特性', 'd4': 'ステイタス特性', 'd5': '事前準備特性','w1': '道路状況把握負担', 'w2': '心身状況負担','w3': '運転ペース阻害負担', 'w4': '車環境負担','w5': '視野環境負担','c1': '写真タイプ', 'c2': '三次元映像タイプ','c3': '言語映像タイプ', 'c4': '言語抽象タイプ','c5': '聴覚言語タイプ', 'c6': '聴覚&音タイプ','p': '行動変容フェーズ', 'none_s': '提示なし','image_s': '画像のみ', 'announce_s': '音声のみ','image_sound_s': '画像+報知音', 'image_announce_s': '画像+音声'}

df_all_drop_exp = df_all_drop_exp.rename(columns=new_column_names)

# %%
df_all_drop_s = df_all_drop_exp[['提示なし', '画像のみ', '音声のみ', '画像+報知音', '画像+音声']]
#df_all_drop_sに関して，'none_s', 'image_s','announce_s', 'image_sound_s', 'image_announce_s'の最大値を持つカラム名をカラムとして追加
df_all_drop_s_max = df_all_drop_s.idxmax(axis=1)
df_all_drop_s_max
# Out:
# 0      画像+報知音
# 1       画像+音声
# 2        音声のみ
# 3       画像+音声
# 4       画像+音声
#         ...
# 635      音声のみ
# 636      音声のみ
# 637      提示なし
# 638     画像+音声
# 639     画像+音声
# Length: 640, dtype: object

# %%
df_all_drop_exp['target'] = df_all_drop_s_max

# %%
#df_all_drop_s_maxをone-hotエンコーディング
df_all_drop_s_max_one_hot = pd.get_dummies(df_all_drop_s_max).astype(int)
df_all_drop_s_max_one_hot
# Out:
#      提示なし  画像+報知音  画像+音声  画像のみ  音声のみ
# 0       0       1      0     0     0
# 1       0       0      1     0     0
# 2       0       0      0     0     1
# 3       0       0      1     0     0
# 4       0       0      1     0     0
# ..    ...     ...    ...   ...   ...
# 635     0       0      0     0     1
# 636     0       0      0     0     1
# 637     1       0      0     0     0
# 638     0       0      1     0     0
# 639     0       0      1     0     0
#
# [640 rows x 5 columns]

# %%
# 特徴量とターゲット変数の設定
features = ['安全運転特性', '不安定な運転特性', '心配性特性', 'ステイタス特性', '事前準備特性',
       '道路状況把握負担', '心身状況負担', '運転ペース阻害負担', '車環境負担', '視野環境負担', '写真タイプ',
       '三次元映像タイプ', '言語映像タイプ', '言語抽象タイプ', '聴覚言語タイプ', '聴覚&音タイプ', '行動変容フェーズ']
# target = ['none_s', 'image_s','announce_s', 'image_sound_s', 'image_announce_s']  

# 特徴量とターゲットの抽出
X = df_all_drop_exp[features]
print(X)
y = df_all_drop_s_max
y
# Out:
#       安全運転特性  不安定な運転特性   心配性特性  ステイタス特性   事前準備特性  道路状況把握負担    心身状況負担  \
# 0     6.2937    1.9398  6.7618  3.07992  5.72156  36.96507  25.87807
# 1     7.1932    2.1034  4.9684  5.66562  8.38533  29.94836  20.88529
# 2     7.8981   -0.9757  4.2858  3.84009  4.87743  26.87720  18.93591
# 3     9.7256    0.0349  7.1680  3.90703  6.30194  43.20713  28.51156
# 4     4.9113    1.4880  3.0357  4.70687  6.26354  26.34567  23.30003
# ..       ...       ...     ...      ...      ...       ...       ...
# 635   7.0463   -1.1722  4.3281  2.71297  7.12817  20.17931  10.61594
# 636   8.5748   -1.1702  4.7669  4.87733  7.84963  27.71802  19.01448
# 637  10.2154   -1.1652  5.1767  2.77794  4.07748  21.64954  14.42384
# 638   8.6738   -0.4216  1.4291  4.27503  5.49286  31.06191  21.50243
# 639   3.5565   -0.0380  3.4472  2.81113  3.50357  30.25131  18.98164
#
#      運転ペース阻害負担     車環境負担    視野環境負担  写真タイプ  三次元映像タイプ  言語映像タイプ  言語抽象タイプ  \
# 0     21.29791  21.00362  14.88221     20        30       29       21
# 1     19.59672  20.50303  14.87523     21        19       18       16
# 2     16.00807  17.58007  11.67031     21        31       28       16
# 3     24.68393  25.27235  19.50599     28        27       23       24
# 4     23.58674  17.89807   9.89196     25        27       16       11
# ..         ...       ...       ...    ...       ...      ...      ...
# 635   10.69781   8.36414  10.69241     22        27       26       31
# 636   16.56406  16.81861  12.86248     26        34       30       14
# 637   14.39132  14.72991  11.08910     16        19       36       13
# 638   19.40287  18.43385  14.97270     15        24       28       26
# 639   19.62766  17.88559  13.44785     29        34       22       16
#
#      聴覚言語タイプ  聴覚&音タイプ  行動変容フェーズ
# 0         10        6         3
# 1         18       15         4
# 2         17       11         4
# 3         24       23         5
# 4         22       22         3
# ..       ...      ...       ...
# 635       21       13         5
# 636       14       10         5
# 637       21       29         2
# 638       17        6         4
# 639       22       10         3
#
# [640 rows x 17 columns]
# 0      画像+報知音
# 1       画像+音声
# 2        音声のみ
# 3       画像+音声
# 4       画像+音声
#         ...
# 635      音声のみ
# 636      音声のみ
# 637      提示なし
# 638     画像+音声
# 639     画像+音声
# Length: 640, dtype: object

# %%
#特徴量ごとに重ねたヒストグラムを作って確認

fig, axes = plt.subplots(4, 3, figsize=(15, 10))
for i in range(4):
    for j in range(3):
        sns.histplot(data=X, x=X.columns[i], hue=y, kde=True, ax=axes[i, j])
plt.tight_layout()
plt.show()

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# # 特徴量のリスト
# features_group_1 = ['安全運転特性', '不安定な運転特性', '心配性特性', 'ステイタス特性']

# # ビンの数を指定
# bin_count = 10  # ここでビンの数を指定

# # カラーパレットを指定
# palette = sns.color_palette("deep", len(df_all_drop_exp['target'].unique()))

# # プロットの作成
# fig, axes = plt.subplots(2, 2, figsize=(20, 15))

# for i, feature in enumerate(features_group_1):
#     ax = axes[i // 2, i % 2]
#     sns.histplot(data=df_all_drop_exp, x=feature, hue='target', kde=True, ax=ax, bins=bin_count, palette=palette)
#     ax.set_title(feature, fontsize=18)
#     ax.set_xlabel('Value', fontsize=16)
#     ax.set_ylabel('Count', fontsize=16)
#     handles, labels = ax.get_legend_handles_labels()
#     ax.legend(handles=handles, labels=labels, fontsize=14)  # レジェンドを手動で追加

# plt.tight_layout()
# plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 特徴量のリスト
features_group_1 = ['安全運転特性', '不安定な運転特性', '心配性特性', 'ステイタス特性']

# ビンの数を指定
bin_count = 10  # ここでビンの数を指定

# プロットの作成
fig, axes = plt.subplots(2, 2, figsize=(20, 15))

for i, feature in enumerate(features_group_1):
    ax = axes[i // 2, i % 2]
    sns.histplot(data=df_all_drop_exp, x=feature, hue='target', kde=True, ax=ax, bins=bin_count)
    ax.set_title(feature, fontsize=18)
    ax.set_xlabel('Value', fontsize=16)
    ax.set_ylabel('Count', fontsize=16)
    handles, labels = ax.get_legend_handles_labels()
    ax.legend(handles=handles, labels=labels, fontsize=14)  # レジェンドを手動で追加

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 特徴量のグループ化
features_group_2 = ['事前準備特性', '道路状況把握負担', '心身状況負担', '運転ペース阻害負担']

# ビンの数を指定
bin_count = 10  # ここでビンの数を指定

# ヒストグラムを作成（次の4つの特徴量）
fig, axes = plt.subplots(2, 2, figsize=(20, 15))

for i, feature in enumerate(features_group_2):
    ax = axes[i // 2, i % 2]
    sns.histplot(data=df_all_drop_exp, x=feature, hue='target', kde=True, ax=ax, bins=bin_count)
    ax.set_title(feature, fontsize=18)
    ax.set_xlabel('Value', fontsize=16)
    ax.set_ylabel('Count', fontsize=16)
    

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 特徴量のリスト
features_group_3 = ['車環境負担', '視野環境負担', '写真タイプ', '三次元映像タイプ']

# プロットの作成
fig, axes = plt.subplots(2, 2, figsize=(20, 15))

for i, feature in enumerate(features_group_3):
    ax = axes[i // 2, i % 2]
    sns.histplot(data=df_all_drop_exp, x=feature, hue='target', kde=True, ax=ax, bins=bin_count)
    ax.set_title(feature, fontsize=18)
    ax.set_xlabel('Value', fontsize=16)
    ax.set_ylabel('Count', fontsize=16)
    ax.legend(fontsize=14)  # レジェンドのフォントサイズを指定

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 特徴量のリスト
features_group_4 = ['言語映像タイプ', '言語抽象タイプ', '聴覚言語タイプ', '聴覚&音タイプ']

# プロットの作成
fig, axes = plt.subplots(2, 2, figsize=(20, 15))

for i, feature in enumerate(features_group_4):
    ax = axes[i // 2, i % 2]
    sns.histplot(data=df_all_drop_exp, x=feature, hue='target', kde=True, ax=ax, bins=bin_count)
    ax.set_title(feature, fontsize=18)
    ax.set_xlabel('Value', fontsize=16)
    ax.set_ylabel('Count', fontsize=16)
    ax.legend(fontsize=14)  # レジェンドのフォントサイズを指定

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 特徴量のリスト
features_group_5 = ['行動変容フェーズ']

# プロットの作成
fig, ax = plt.subplots(1, 1, figsize=(10, 7.5))

sns.histplot(data=df_all_drop_exp, x=features_group_5[0], hue='target', kde=True, ax=ax, bins=bin_count)
ax.set_title(features_group_5[0], fontsize=18)
ax.set_xlabel('Value', fontsize=16)
ax.set_ylabel('Count', fontsize=16)
ax.legend(fontsize=14)  # レジェンドのフォントサイズを指定

plt.tight_layout()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import matplotlib.pyplot as plt

# 特徴量のグループ化
features_group_1 = [ '心配性特性', 'ステイタス特性']

# ヒストグラムを作成（最初の4つの特徴量）
fig = plt.figure(figsize=(20, 15))

for i, feature in enumerate(features_group_1):
    ax = fig.add_subplot(2, 2, i+1)
    for target in df_all_drop_exp['target'].unique():
        ax.hist(df_all_drop_exp[df_all_drop_exp['target'] == target][feature], bins=10, alpha=0.4, label=target)
    ax.set_title(feature, fontsize=18)
    ax.set_xlabel('Value', fontsize=16)
    ax.set_ylabel('Count', fontsize=16)
    ax.legend(fontsize=14)

plt.subplots_adjust(wspace=0.3, hspace=0.3)
plt.savefig('img_driving/img_driving_ave/fig1.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# 特徴量のグループ化
features_group_2 = ['事前準備特性', '道路状況把握負担', '心身状況負担', '運転ペース阻害負担']

# ヒストグラムを作成（次の4つの特徴量）
fig = plt.figure(figsize=(20, 15))

for i, feature in enumerate(features_group_2):
    ax = fig.add_subplot(2, 2, i+1)
    for target in df_all_drop_exp['target'].unique():
        ax.hist(df_all_drop_exp[df_all_drop_exp['target'] == target][feature], bins=10, alpha=0.4, label=target)
    ax.set_title(feature, fontsize=18)
    ax.set_xlabel('Value', fontsize=16)
    ax.set_ylabel('Count', fontsize=16)
    ax.legend(fontsize=14)

plt.subplots_adjust(wspace=0.3, hspace=0.3)
plt.savefig('img_driving/img_driving_ave/fig2.png')
plt.show()

# %%
import matplotlib.pyplot as plt

# 特徴量のグループ化
features_group_3 = ['車環境負担', '視野環境負担', '写真タイプ', '三次元映像タイプ']

# ヒストグラムを作成（さらに次の4つの特徴量）
fig = plt.figure(figsize=(20, 15))

for i, feature in enumerate(features_group_3):
    ax = fig.add_subplot(2, 2, i+1)
    for target in df_all_drop_exp['target'].unique():
        ax.hist(df_all_drop_exp[df_all_drop_exp['target'] == target][feature], bins=10, alpha=0.4, label=target)
    ax.set_title(feature, fontsize=18)
    ax.set_xlabel('Value', fontsize=16)
    ax.set_ylabel('Count', fontsize=16)
    ax.legend(fontsize=14)

plt.subplots_adjust(wspace=0.3, hspace=0.3)
plt.show()

# %%
import matplotlib.pyplot as plt

# 特徴量のグループ化
features_group_4 = ['言語映像タイプ', '言語抽象タイプ', '聴覚言語タイプ', '聴覚&音タイプ']

# ヒストグラムを作成（さらに次の4つの特徴量）
fig = plt.figure(figsize=(20, 15))

for i, feature in enumerate(features_group_4):
    ax = fig.add_subplot(2, 2, i+1)
    for target in df_all_drop_exp['target'].unique():
        ax.hist(df_all_drop_exp[df_all_drop_exp['target'] == target][feature], bins=10, alpha=0.4, label=target)
    ax.set_title(feature, fontsize=18)
    ax.set_xlabel('Value', fontsize=16)
    ax.set_ylabel('Count', fontsize=16)
    ax.legend(fontsize=14)

plt.subplots_adjust(wspace=0.3, hspace=0.3)
plt.show()

# %%
# import matplotlib.pyplot as plt

# # 特徴量のグループ化
# features_group_5 = ['年齢']

# # ヒストグラムを作成（最後の1つの特徴量）
# fig = plt.figure(figsize=(10, 7.5))

# for i, feature in enumerate(features_group_5):
#     ax = fig.add_subplot(1, 1, i+1)
#     for target in df_all_drop_exp['target'].unique():
#         ax.hist(df_all_drop_exp[df_all_drop_exp['target'] == target][feature], bins=6, alpha=0.4, label=target)
#     ax.set_title(feature, fontsize=18)
#     ax.set_xlabel('Value', fontsize=16)
#     ax.set_ylabel('Count', fontsize=16)
#     ax.legend(fontsize=14)

# plt.subplots_adjust(wspace=0.3, hspace=0.3)
# plt.show()

# %%
# #年齢の分布を確認
# plt.hist(df_all_drop_exp['年齢'], bins=6)
# plt.title('年齢の分布', fontsize=18)
# plt.xlabel('年齢', fontsize=16)
# plt.ylabel('Count', fontsize=16)

# plt.show()

# %%
# import matplotlib.pyplot as plt

# # 特徴量のグループ化
# features_group_5 = ['年齢']

# # ヒストグラムを作成（最後の1つの特徴量）
# fig = plt.figure(figsize=(10, 7.5))

# for i, feature in enumerate(features_group_5):
#     ax = fig.add_subplot(1, 1, i+1)
#     for target in df_all_drop_exp['target'].unique():
#         ax.hist(df_all_drop_exp[df_all_drop_exp['target'] == target][feature], bins=8, alpha=0.4, label=target)
#     ax.set_title(feature, fontsize=18)
#     ax.set_xlabel('Value', fontsize=16)
#     ax.set_ylabel('Count', fontsize=16)
#     ax.legend(fontsize=14)

# plt.subplots_adjust(wspace=0.3, hspace=0.3)
# plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: '年齢'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[33], line 12
#      10 ax = fig.add_subplot(1, 1, i+1)
#      11 for target in df_all_drop_exp['target'].unique():
# ---> 12     ax.hist(df_all_drop_exp[df_all_drop_exp['target'] == target][feature], bins=8, alpha=0.4, label=target)
#      13 ax.set_title(feature, fontsize=18)
#      14 ax.set_xlabel('Value', fontsize=16)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: '年齢'

# %%
#d1ごとのyの値の分布
#d1の値を10分割
df_all_drop_exp['安全運転特性_d'] = pd.cut(df_all_drop_exp['安全運転特性'], 7)
sns.countplot(x='安全運転特性_d', hue=y, data=df_all_drop_exp)
# plt.savefig('img_countplot/d1.png')
plt.show()

# %%
#d2ごとのyの値の分布
#d2の値を10分割
df_all_drop_exp['不安定な運転特性_d'] = pd.cut(df_all_drop_exp['不安定な運転特性'], 4)
sns.countplot(x='不安定な運転特性_d', hue=y, data=df_all_drop_exp)
# Out:
# <Axes: xlabel='不安定な運転特性_d', ylabel='count'>

# %%
# #d3ごとのyの値の分布
# #d3の値を10分割 
# df_all_drop_exp['d3_d'] = pd.cut(df_all_drop_exp['d3'], 5)
# sns.countplot(x='d3_d', hue=y, data=df_all_drop_exp)

# %%
# #pごとのyの値の分布

# sns.countplot(x='p', hue=y, data=df_all_drop_exp)

# %%
#t-sne
#空間が分離できているかどうかの確認
from sklearn.manifold import TSNE
tsne = TSNE(n_components=2, random_state=0)
tsne.fit(X)
x = tsne.fit_transform(X)

#xとyを結合
x = pd.DataFrame(x, columns=['x1', 'x2'])
x['feedback'] = y

#クラスタリング結果の可視化
sns.scatterplot(x='x1', y='x2', hue='feedback', data=x)
plt.savefig('img_tsne/tsne_visualization.png')  # 画像を保存
plt.show()

# %%
#k-means
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=5, random_state=0)
kmeans.fit(X)
df_all_drop_exp['cluster'] = kmeans.labels_
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
#クラスタリング結果の可視化
plt.scatter(x['x1'], x['x2'], c=df_all_drop_exp['cluster'])
plt.colorbar()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 #クラスタリング結果の可視化
# ----> 2 plt.scatter(x['x1'], x['x2'], c=df_all_drop_exp['cluster'])
#       3 plt.colorbar()
#       4 plt.show()
#
# NameError: name 'x' is not defined

# %%
#各クラスタのサンプル数
df_all_drop_exp['cluster'].value_counts()
# Out:
# cluster
# 3    147
# 1    134
# 0    130
# 4    120
# 2    109
# Name: count, dtype: int64

# %%
#クラスタごとの特徴量の平均値
df_all_drop_exp.groupby('cluster').mean()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:849, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     847     preserve_dtype = True
# --> 849 result = self._aggregate_series_pure_python(obj, func)
#     851 if len(obj) == 0 and len(result) == 0 and isinstance(obj.dtype, ExtensionDtype):
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/ops.py:877, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     876 for i, group in enumerate(splitter):
# --> 877     res = func(group)
#     878     res = extract_result(res)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2380, in GroupBy.mean.<locals>.<lambda>(x)
#    2377 else:
#    2378     result = self._cython_agg_general(
#    2379         "mean",
# -> 2380         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2381         numeric_only=numeric_only,
#    2382     )
#    2383     return result.__finalize__(self.obj, method="groupby")
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6225, in Series.mean(self, axis, skipna, numeric_only, **kwargs)
#    6217 @doc(make_doc("mean", ndim=1))
#    6218 def mean(
#    6219     self,
#    (...)
#    6223     **kwargs,
#    6224 ):
# -> 6225     return NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11992, in NDFrame.mean(self, axis, skipna, numeric_only, **kwargs)
#   11985 def mean(
#   11986     self,
#   11987     axis: Axis | None = 0,
#    (...)
#   11990     **kwargs,
#   11991 ) -> Series | float:
# > 11992     return self._stat_function(
#   11993         "mean", nanops.nanmean, axis, skipna, numeric_only, **kwargs
#   11994     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/generic.py:11949, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   11947 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 11949 return self._reduce(
#   11950     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   11951 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/series.py:6133, in Series._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#    6129     raise TypeError(
#    6130         f"Series.{name} does not allow {kwd_name}={numeric_only} "
#    6131         "with non-numeric dtypes."
#    6132     )
# -> 6133 return op(delegate, skipna=skipna, **kwds)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:720, in nanmean(values, axis, skipna, mask)
#     719 the_sum = values.sum(axis, dtype=dtype_sum)
# --> 720 the_sum = _ensure_numeric(the_sum)
#     722 if axis is not None and getattr(the_sum, "ndim", False):
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/nanops.py:1693, in _ensure_numeric(x)
#    1691 if isinstance(x, str):
#    1692     # GH#44008, GH#36703 avoid casting e.g. strings to numeric
# -> 1693     raise TypeError(f"Could not convert string '{x}' to numeric")
#    1694 try:
#
# TypeError: Could not convert string '画像+音声画像のみ画像+報知音画像+音声画像のみ画像+音声画像+音声音声のみ音声のみ音声のみ画像+音声画像+音声音声のみ画像+報知音音声のみ音声のみ画像+音声音声のみ画像+音声画像のみ画像+音声画像+報知音画像+音声音声のみ画像+音声画像+報知音音声のみ画像+音声画像+音声画像+報知音画像+音声画像+音声画像+音声画像+報知音画像のみ画像+音声音声のみ画像+報知音画像+音声画像+音声音声のみ音声のみ画像+音声音声のみ画像+報知音音声のみ音声のみ音声のみ画像+音声画像+音声画像のみ音声のみ音声のみ画像+音声画像+報知音画像+音声画像+音声音声のみ音声のみ画像+音声画像+音声画像のみ音声のみ画像のみ音声のみ画像+音声画像のみ画像のみ画像+音声画像+音声画像+音声画像+音声音声のみ画像+音声画像+報知音画像+報知音画像+報知音音声のみ音声のみ画像のみ画像+音声画像+報知音画像+音声音声のみ画像+音声画像+音声画像のみ画像+報知音画像+音声音声のみ音声のみ画像+音声画像+音声画像のみ画像+音声画像のみ提示なし画像+音声音声のみ音声のみ音声のみ画像+音声音声のみ音声のみ音声のみ画像+音声画像のみ音声のみ画像+音声画像+音声画像+報知音画像+音声画像+音声画像+音声画像のみ画像+報知音画像+報知音音声のみ画像+音声画像+音声音声のみ画像のみ音声のみ画像+音声音声のみ画像+音声音声のみ音声のみ音声のみ画像+音声' to numeric
#
# The above exception was the direct cause of the following exception:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[37], line 2
#       1 #クラスタごとの特徴量の平均値
# ----> 2 df_all_drop_exp.groupby('cluster').mean()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:2378, in GroupBy.mean(self, numeric_only, engine, engine_kwargs)
#    2371     return self._numba_agg_general(
#    2372         grouped_mean,
#    2373         executor.float_dtype_mapping,
#    2374         engine_kwargs,
#    2375         min_periods=0,
#    2376     )
#    2377 else:
# -> 2378     result = self._cython_agg_general(
#    2379         "mean",
#    2380         alt=lambda x: Series(x).mean(numeric_only=numeric_only),
#    2381         numeric_only=numeric_only,
#    2382     )
#    2383     return result.__finalize__(self.obj, method="groupby")
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1929, in GroupBy._cython_agg_general(self, how, alt, numeric_only, min_count, **kwargs)
#    1926     result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927     return result
# -> 1929 new_mgr = data.grouped_reduce(array_func)
#    1930 res = self._wrap_agged_manager(new_mgr)
#    1931 out = self._wrap_aggregated_output(res)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/internals/managers.py:1428, in BlockManager.grouped_reduce(self, func)
#    1424 if blk.is_object:
#    1425     # split on object-dtype blocks bc some columns may raise
#    1426     #  while others do not.
#    1427     for sb in blk._split():
# -> 1428         applied = sb.apply(func)
#    1429         result_blocks = extend_blocks(applied, result_blocks)
#    1430 else:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/internals/blocks.py:366, in Block.apply(self, func, **kwargs)
#     360 @final
#     361 def apply(self, func, **kwargs) -> list[Block]:
#     362     """
#     363     apply the function to my values; return a block if we are not
#     364     one
#     365     """
# --> 366     result = func(self.values, **kwargs)
#     368     result = maybe_coerce_values(result)
#     369     return self._split_op_result(result)
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1926, in GroupBy._cython_agg_general.<locals>.array_func(values)
#    1923 else:
#    1924     return result
# -> 1926 result = self._agg_py_fallback(how, values, ndim=data.ndim, alt=alt)
#    1927 return result
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1878, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1876     msg = f"agg function failed [how->{how},dtype->{ser.dtype}]"
#    1877     # preserve the kind of exception that raised
# -> 1878     raise type(err)(msg) from err
#    1880 if ser.dtype == object:
#    1881     res_values = res_values.astype(object, copy=False)
#
# TypeError: agg function failed [how->mean,dtype->object]

# %%
#各クラスタごとのデータを確認
df_all_drop_exp[df_all_drop_exp['cluster'] == 0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cluster'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 2
#       1 #各クラスタごとのデータを確認
# ----> 2 df_all_drop_exp[df_all_drop_exp['cluster'] == 0]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'cluster'

# %%
#クラスタ1の特徴量の分布
df_all_drop_exp[df_all_drop_exp['cluster']==1].hist()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cluster'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[51], line 2
#       1 #クラスタ1の特徴量の分布
# ----> 2 df_all_drop_exp[df_all_drop_exp['cluster']==1].hist()
#       3 plt.show()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'cluster'

# %%
import matplotlib.pyplot as plt

# クラスタ1の特徴量の分布
plt.figure(figsize=(20, 15))  # 表示サイズを指定
df_all_drop_exp[df_all_drop_exp['cluster'] == 1].hist()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'cluster'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[52], line 5
#       3 # クラスタ1の特徴量の分布
#       4 plt.figure(figsize=(20, 15))  # 表示サイズを指定
# ----> 5 df_all_drop_exp[df_all_drop_exp['cluster'] == 1].hist()
#       6 plt.show()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'cluster'

# %%
#クラスタごとの特徴量の分布(ヒストグラム)
#サイズの調整
plt.figure(figsize=(100, 30))
df_all_drop_exp.groupby('cluster').hist()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[53], line 4
#       1 #クラスタごとの特徴量の分布(ヒストグラム)
#       2 #サイズの調整
#       3 plt.figure(figsize=(100, 30))
# ----> 4 df_all_drop_exp.groupby('cluster').hist()
#       5 plt.show()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
#    8876     group_keys=group_keys,
#    8877     observed=observed,
#    8878     dropna=dropna,
#    8879 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1278, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1275 self.dropna = dropna
#    1277 if grouper is None:
# -> 1278     grouper, exclusions, obj = get_grouper(
#    1279         obj,
#    1280         keys,
#    1281         axis=axis,
#    1282         level=level,
#    1283         sort=sort,
#    1284         observed=False if observed is lib.no_default else observed,
#    1285         dropna=self.dropna,
#    1286     )
#    1288 if observed is lib.no_default:
#    1289     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/grouper.py:1009, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1007         in_axis, level, gpr = False, gpr, None
#    1008     else:
# -> 1009         raise KeyError(gpr)
#    1010 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1011     # Add key to exclusions
#    1012     exclusions.add(gpr.key)
#
# KeyError: 'cluster'

# %%
#クラスタごとの特徴量の分布(箱ひげ図)
#サイズの調整
plt.figure(figsize=(100, 30))
df_all_drop_exp.boxplot(by='cluster')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[54], line 4
#       1 #クラスタごとの特徴量の分布(箱ひげ図)
#       2 #サイズの調整
#       3 plt.figure(figsize=(100, 30))
# ----> 4 df_all_drop_exp.boxplot(by='cluster')
#       5 plt.show()
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_core.py:529, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, backend, **kwargs)
#     512 @Substitution(data="", backend=_backend_doc)
#     513 @Appender(_boxplot_doc)
#     514 def boxplot_frame(
#    (...)
#     526     **kwargs,
#     527 ):
#     528     plot_backend = _get_plot_backend(backend)
# --> 529     return plot_backend.boxplot_frame(
#     530         self,
#     531         column=column,
#     532         by=by,
#     533         ax=ax,
#     534         fontsize=fontsize,
#     535         rot=rot,
#     536         grid=grid,
#     537         figsize=figsize,
#     538         layout=layout,
#     539         return_type=return_type,
#     540         **kwargs,
#     541     )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_matplotlib/boxplot.py:470, in boxplot_frame(self, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     455 def boxplot_frame(
#     456     self,
#     457     column=None,
#    (...)
#     466     **kwds,
#     467 ):
#     468     import matplotlib.pyplot as plt
# --> 470     ax = boxplot(
#     471         self,
#     472         column=column,
#     473         by=by,
#     474         ax=ax,
#     475         fontsize=fontsize,
#     476         grid=grid,
#     477         rot=rot,
#     478         figsize=figsize,
#     479         layout=layout,
#     480         return_type=return_type,
#     481         **kwds,
#     482     )
#     483     plt.draw_if_interactive()
#     484     return ax
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_matplotlib/boxplot.py:416, in boxplot(data, column, by, ax, fontsize, rot, grid, figsize, layout, return_type, **kwds)
#     411     columns = [column]
#     413 if by is not None:
#     414     # Prefer array return type for 2-D plots to match the subplot layout
#     415     # https://github.com/pandas-dev/pandas/pull/12216#issuecomment-241175580
# --> 416     result = _grouped_plot_by_column(
#     417         plot_group,
#     418         data,
#     419         columns=columns,
#     420         by=by,
#     421         grid=grid,
#     422         figsize=figsize,
#     423         ax=ax,
#     424         layout=layout,
#     425         return_type=return_type,
#     426         **kwds,
#     427     )
#     428 else:
#     429     if return_type is None:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/plotting/_matplotlib/boxplot.py:258, in _grouped_plot_by_column(plotf, data, columns, by, numeric_only, grid, figsize, ax, layout, return_type, **kwargs)
#     245 def _grouped_plot_by_column(
#     246     plotf,
#     247     data,
#    (...)
#     256     **kwargs,
#     257 ):
# --> 258     grouped = data.groupby(by, observed=False)
#     259     if columns is None:
#     260         if not isinstance(by, (list, tuple)):
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
#    8876     group_keys=group_keys,
#    8877     observed=observed,
#    8878     dropna=dropna,
#    8879 )
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/groupby.py:1278, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1275 self.dropna = dropna
#    1277 if grouper is None:
# -> 1278     grouper, exclusions, obj = get_grouper(
#    1279         obj,
#    1280         keys,
#    1281         axis=axis,
#    1282         level=level,
#    1283         sort=sort,
#    1284         observed=False if observed is lib.no_default else observed,
#    1285         dropna=self.dropna,
#    1286     )
#    1288 if observed is lib.no_default:
#    1289     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/groupby/grouper.py:1009, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1007         in_axis, level, gpr = False, gpr, None
#    1008     else:
# -> 1009         raise KeyError(gpr)
#    1010 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1011     # Add key to exclusions
#    1012     exclusions.add(gpr.key)
#
# KeyError: 'cluster'

# %%
#シルエット係数
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
silhouette_scores = []
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(X)
    silhouette_scores.append(silhouette_score(X, kmeans.labels_))
plt.plot(range(2, 11), silhouette_scores)
plt.xlabel("Number of clusters")
plt.ylabel("Silhouette score")
plt.show()
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /opt/anaconda3/lib/python3.11/site-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
# 特徴量とターゲット変数の設定
features = ['d1', 'd2', 'd3', 'd4', 'd5']
X = df_all_drop_exp[features]
#シルエット係数
from sklearn.metrics import silhouette_score
from sklearn.cluster import KMeans
silhouette_scores = []
for i in range(2, 11):
    kmeans = KMeans(n_clusters=i, random_state=0)
    kmeans.fit(X)
    silhouette_scores.append(silhouette_score(X, kmeans.labels_))
plt.plot(range(2, 11), silhouette_scores)
plt.xlabel("Number of clusters")
plt.ylabel("Silhouette score")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[55], line 3
#       1 # 特徴量とターゲット変数の設定
#       2 features = ['d1', 'd2', 'd3', 'd4', 'd5']
# ----> 3 X = df_all_drop_exp[features]
#       4 #シルエット係数
#       5 from sklearn.metrics import silhouette_score
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
#    6118 if isinstance(key, Index):
#    6119     # GH 42790 - Preserve name from an Index
#
# File /opt/anaconda3/lib/python3.11/site-packages/pandas/core/indexes/base.py:6176, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6174     if use_interval_msg:
#    6175         key = list(key)
# -> 6176     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6178 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
#    6179 raise KeyError(f"{not_found} not in index")
#
# KeyError: "None of [Index(['d1', 'd2', 'd3', 'd4', 'd5'], dtype='object')] are in the [columns]"

# %%
#階層的クラスタリング
from scipy.cluster.hierarchy import linkage, dendrogram
import matplotlib.pyplot as plt
# クラスタリングの実行
result1 = linkage(X, method='ward')
# デンドログラムの表示
dendrogram(result1)
plt.show()
